# %%
# standard
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pl

# os
import os

# sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# tf
import tensorflow as tf
import tensorflow_probability as tfp
tfd = tfp.distributions
tfb = tfp.bijectors

# keras
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Layer, Input, Activation, Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras import optimizers
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K
from keras.regularizers import l1,l2
from keras.utils.vis_utils import plot_model

# %%
# Import data
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Make pd df
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Mushroom Classification Project/mushrooms.csv')

# %% [markdown]
# #### Data Topology:
#
# -	cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
# -	cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
# -	cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y
# -	bruises: bruises=t,no=f
# -	odor: almond=a,anise=l,creosote=c,fishy=y,foul=f,musty=m,none=n,pungent=p,spicy=s
# -	gill-attachment: attached=a,descending=d,free=f,notched=n
# -	gill-spacing: close=c,crowded=w,distant=d
# -	gill-size: broad=b,narrow=n
# -	gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e,white=w,yellow=y
# -	stalk-shape: enlarging=e,tapering=t
# -	stalk-root: bulbous=b,club=c,cup=u,equal=e,rhizomorphs=z,rooted=r,missing=?
# -	stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
# -	stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
# -	stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
# -	stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
# -	veil-type: partial=p,universal=u
# -	veil-color: brown=n,orange=o,white=w,yellow=y
# -	ring-number: none=n,one=o,two=t
# -	ring-type: cobwebby=c,evanescent=e,flaring=f,large=l,none=n,pendant=p,sheathing=s,zone=z
# -	spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r,orange=o,purple=u,white=w,yellow=y
# -	population: abundant=a,clustered=c,numerous=n,scattered=s,several=v,solitary=y
# -	habitat: grasses=g,leaves=l,meadows=m,paths=p,urban=u,waste=w,woods=d

# %%
# Categorical encoding

for feat in df.columns:
    # extract unique column values
    vals = np.unique(df[feat].values)
    # fit labelencoder
    le = LabelEncoder()
    le.fit(df[feat])
    # transform dataset
    df[feat] = le.transform(df[feat])

# %%
# Extract list of training features
tfeatures = np.array(df.columns)[1:]
features = np.array(df.columns)

# %%
# Split into train/target
_target = df.pop('class')
_train = df

# %%
# Train size
train_size = 6499

# Make train/test data
x_train = {}
x_test = {}
y_train = []
y_test = []

# %%
# Populate x_train, x_test
for f in tfeatures:
    x_train[f] = _train[f][:train_size+1]
    x_test[f] = _train[f][train_size:]

# %%
# Populate y_train, y_test
y_train = _target[:train_size+1]
y_test = _target[train_size:]

# %%
# Custom activation function
def swish(x):
    return (K.sigmoid(x) * x)

get_custom_objects().update({'swish': Activation(swish)})

# %%
# Custom loss function
def neg_log_likelihood(targets, estimate):
    return -estimate.log_prob(targets)

# %%
# BNN Model

# Prior weights will remain fixed and untrained
#   mean = 0
#   std-dev = 1
def prior_weights_model(kernel_size, bias_size, dtype = None):
    units = kernel_size + bias_size
    pw = Sequential()
    pw.add(
        tfp.layers.DistributionLambda(
            lambda x: tfd.MultivariateNormalDiag(loc = tf.zeros(units), 
                                                 scale_diag = tf.ones(units) )
        ) 
    )
    return pw

# Posterior weights will be trained and unfixed
#   learnable params are mean, variance, and covariance
def posterior_inference_model(kernel_size, bias_size, dtype = None):
    units = kernel_size + bias_size
    pi = Sequential()
    pi.add(
        tfp.layers.VariableLayer(
            tfp.layers.MultivariateNormalTriL.params_size(units), dtype = dtype
        )
    )
    pi.add(
        tfp.layers.MultivariateNormalTriL(units)
    )
    return pi

# This function will produce an input tensor for each feature extracted from the df
#   keras.layers.Input produces a keras tensor with a specific feature name
#   this will allow us to later quantify inference for each feature
def populate_input_tensors(_features = tfeatures):
    inputs = {}
    for f in _features:
        inputs[f] = Input(name = f, shape = (1,), dtype = tf.float32)
    return inputs

# training_size = len(x_train)
def _BNN(n_units = 2, lr = 0.001, training_size = 6500, hidden_units = 10, activ = 'sigmoid'):
    input_layers = populate_input_tensors()
    feature_layers = keras.layers.concatenate( list(input_layers.values()) )
    feature_layers = keras.layers.BatchNormalization()(feature_layers)

    for u in np.full(shape = n_units, fill_value = hidden_units):
        feature_layers = tfp.layers.DenseVariational(
            units = u,
            make_posterior_fn = posterior_inference_model,
            make_prior_fn = prior_weights_model,
            kl_weight = 1 / training_size,
            activation = activ)(feature_layers)

    # Probabilistic output model
    #   Dense layer: used to produce distribution parameters
    #   IndependentBernoulli: used for binary classification
    dist_params = Dense(units = 2)(feature_layers)
    output_layers = tfp.layers.IndependentBernoulli(2)(dist_params)

    model = keras.Model(inputs = input_layers, outputs = output_layers)
    model.compile(optimizer = keras.optimizers.RMSprop(learning_rate = lr), 
                  metrics = [keras.metrics.RootMeanSquaredError()], 
                  loss = neg_log_likelihood)
    return model

# %%
params = {
    'bnn_a1':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':6, 'lr':0.005, 'activ':'sigmoid', 'label':'BNN A - lr=5e-3', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_a2':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':6, 'lr':0.01, 'activ':'sigmoid', 'label':'BNN A - lr=1e-2', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_b1':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':8, 'lr':0.005, 'activ':'sigmoid', 'label':'BNN B - lr=5e-3', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_b2':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':8, 'lr':0.01, 'activ':'sigmoid', 'label':'BNN B - lr=1e-2', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''}
}

# %%
# Parameters
n_epoches = 500
batch_size = 128

# %%
# Train cross-validated NN model
for k in params.keys():
    tf.random.set_seed(0)
    model = params[k]['function'](n_units = params[k]['n_units'], lr = params[k]['lr'], training_size = len(y_train), hidden_units = params[k]['hidden_units'])
    params[k]['history'] = model.fit(x = x_train, y = y_train, validation_data = (x_test, y_test), epochs = n_epoches, batch_size = batch_size, shuffle = True)
    params[k]['model'] = model
# Out:
# Epoch 1/500
# 51/51 [==============================] - 7s 23ms/step - loss: 1.3927 - root_mean_squared_error: 0.6997 - val_loss: 1.5840 - val_root_mean_squared_error: 0.7222
# Epoch 2/500
# 51/51 [==============================] - 0s 6ms/step - loss: 1.3773 - root_mean_squared_error: 0.7017 - val_loss: 1.4505 - val_root_mean_squared_error: 0.7271
# Epoch 3/500
# 51/51 [==============================] - 0s 6ms/step - loss: 1.3737 - root_mean_squared_error: 0.7038 - val_loss: 1.4774 - val_root_mean_squared_error: 0.7155
# Epoch 4/500
# 51/51 [==============================] - 0s 6ms/step - loss: 1.3670 - root_mean_squared_error: 0.6955 - val_loss: 1.4599 - val_root_mean_squared_error: 0.7228
# Epoch 5/500
# 51/51 [==============================] - 0s 6ms/step - loss: 1.3347 - root_mean_squared_error: 0.6886 - val_loss: 1.3736 - val_root_mean_squared_error: 0.7023
# Epoch 6/500
# 51/51 [==============================] - 0s 6ms/step - loss: 1.2832 - root_mean_squared_error: 0.6787 - val_loss: 1.2881 - val_root_mean_squared_error: 0.6760
# Epoch 7/500
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1830 - root_mean_squared_error: 0.6559 - val_loss: 1.1308 - val_root_mean_squared_error: 0.6509
# Epoch 8/500
# 51/51 [==============================] - 0s 8ms/step - loss: 1.0392 - root_mean_squared_error: 0.6220 - val_loss: 1.0415 - val_root_mean_squared_error: 0.6129
# Epoch 9/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.8675 - root_mean_squared_error: 0.5656 - val_loss: 0.8013 - val_root_mean_squared_error: 0.5384
# Epoch 10/500
# 51/51 [==============================] - 0s 9ms/step - loss: 0.7491 - root_mean_squared_error: 0.5199 - val_loss: 0.5903 - val_root_mean_squared_error: 0.4781
# Epoch 11/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.6400 - root_mean_squared_error: 0.4650 - val_loss: 0.5728 - val_root_mean_squared_error: 0.4476
# Epoch 12/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.5829 - root_mean_squared_error: 0.4334 - val_loss: 0.4880 - val_root_mean_squared_error: 0.3871
# Epoch 13/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.5317 - root_mean_squared_error: 0.4027 - val_loss: 0.5297 - val_root_mean_squared_error: 0.4184
# Epoch 14/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.5053 - root_mean_squared_error: 0.3901 - val_loss: 0.3139 - val_root_mean_squared_error: 0.3360
# Epoch 15/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.4672 - root_mean_squared_error: 0.3599 - val_loss: 0.3804 - val_root_mean_squared_error: 0.3491
# Epoch 16/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.4849 - root_mean_squared_error: 0.3580 - val_loss: 0.3801 - val_root_mean_squared_error: 0.3182
# Epoch 17/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.4501 - root_mean_squared_error: 0.3457 - val_loss: 0.5715 - val_root_mean_squared_error: 0.3961
# Epoch 18/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.4197 - root_mean_squared_error: 0.3313 - val_loss: 0.2778 - val_root_mean_squared_error: 0.3053
# Epoch 19/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.4429 - root_mean_squared_error: 0.3350 - val_loss: 0.3375 - val_root_mean_squared_error: 0.3291
# Epoch 20/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.4319 - root_mean_squared_error: 0.3317 - val_loss: 0.4688 - val_root_mean_squared_error: 0.3646
# Epoch 21/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.4094 - root_mean_squared_error: 0.3153 - val_loss: 0.3628 - val_root_mean_squared_error: 0.3220
# Epoch 22/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.4110 - root_mean_squared_error: 0.3257 - val_loss: 0.3766 - val_root_mean_squared_error: 0.3365
# Epoch 23/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.4025 - root_mean_squared_error: 0.3200 - val_loss: 0.3135 - val_root_mean_squared_error: 0.2946
# Epoch 24/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.4007 - root_mean_squared_error: 0.3183 - val_loss: 0.3848 - val_root_mean_squared_error: 0.3263
# Epoch 25/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3893 - root_mean_squared_error: 0.3070 - val_loss: 0.4279 - val_root_mean_squared_error: 0.3406
# Epoch 26/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3886 - root_mean_squared_error: 0.3047 - val_loss: 0.4352 - val_root_mean_squared_error: 0.3774
# Epoch 27/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3738 - root_mean_squared_error: 0.3058 - val_loss: 0.4747 - val_root_mean_squared_error: 0.3633
# Epoch 28/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3699 - root_mean_squared_error: 0.2983 - val_loss: 0.4872 - val_root_mean_squared_error: 0.3333
# Epoch 29/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3420 - root_mean_squared_error: 0.2919 - val_loss: 0.4656 - val_root_mean_squared_error: 0.3388
# Epoch 30/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3655 - root_mean_squared_error: 0.2937 - val_loss: 0.4556 - val_root_mean_squared_error: 0.3521
# Epoch 31/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3709 - root_mean_squared_error: 0.3028 - val_loss: 0.3060 - val_root_mean_squared_error: 0.2796
# Epoch 32/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3543 - root_mean_squared_error: 0.3010 - val_loss: 0.2881 - val_root_mean_squared_error: 0.2790
# Epoch 33/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3548 - root_mean_squared_error: 0.2935 - val_loss: 0.3520 - val_root_mean_squared_error: 0.3018
# Epoch 34/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3563 - root_mean_squared_error: 0.2843 - val_loss: 0.4562 - val_root_mean_squared_error: 0.3451
# Epoch 35/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3701 - root_mean_squared_error: 0.2917 - val_loss: 0.3584 - val_root_mean_squared_error: 0.3033
# Epoch 36/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3503 - root_mean_squared_error: 0.2862 - val_loss: 0.5336 - val_root_mean_squared_error: 0.3437
# Epoch 37/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3430 - root_mean_squared_error: 0.2882 - val_loss: 0.2868 - val_root_mean_squared_error: 0.2785
# Epoch 38/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3549 - root_mean_squared_error: 0.2921 - val_loss: 0.4913 - val_root_mean_squared_error: 0.3688
# Epoch 39/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3193 - root_mean_squared_error: 0.2819 - val_loss: 0.6788 - val_root_mean_squared_error: 0.4304
# Epoch 40/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3517 - root_mean_squared_error: 0.2855 - val_loss: 0.3607 - val_root_mean_squared_error: 0.2861
# Epoch 41/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3309 - root_mean_squared_error: 0.2785 - val_loss: 0.3516 - val_root_mean_squared_error: 0.2951
# Epoch 42/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3179 - root_mean_squared_error: 0.2705 - val_loss: 0.3484 - val_root_mean_squared_error: 0.2961
# Epoch 43/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3239 - root_mean_squared_error: 0.2793 - val_loss: 0.4575 - val_root_mean_squared_error: 0.3388
# Epoch 44/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3185 - root_mean_squared_error: 0.2649 - val_loss: 0.5690 - val_root_mean_squared_error: 0.3843
# Epoch 45/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3251 - root_mean_squared_error: 0.2820 - val_loss: 0.4362 - val_root_mean_squared_error: 0.3324
# Epoch 46/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3269 - root_mean_squared_error: 0.2743 - val_loss: 0.4383 - val_root_mean_squared_error: 0.3424
# Epoch 47/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3218 - root_mean_squared_error: 0.2816 - val_loss: 0.3549 - val_root_mean_squared_error: 0.2951
# Epoch 48/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3201 - root_mean_squared_error: 0.2733 - val_loss: 0.3211 - val_root_mean_squared_error: 0.3003
# Epoch 49/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3181 - root_mean_squared_error: 0.2683 - val_loss: 0.3973 - val_root_mean_squared_error: 0.3365
# Epoch 50/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3156 - root_mean_squared_error: 0.2741 - val_loss: 0.6860 - val_root_mean_squared_error: 0.4053
# Epoch 51/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3231 - root_mean_squared_error: 0.2754 - val_loss: 0.6153 - val_root_mean_squared_error: 0.3679
# Epoch 52/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3275 - root_mean_squared_error: 0.2715 - val_loss: 0.3795 - val_root_mean_squared_error: 0.3058
# Epoch 53/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3304 - root_mean_squared_error: 0.2860 - val_loss: 0.4342 - val_root_mean_squared_error: 0.3177
# Epoch 54/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3002 - root_mean_squared_error: 0.2722 - val_loss: 0.4116 - val_root_mean_squared_error: 0.3063
# Epoch 55/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3081 - root_mean_squared_error: 0.2624 - val_loss: 0.4847 - val_root_mean_squared_error: 0.3305
# Epoch 56/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3042 - root_mean_squared_error: 0.2653 - val_loss: 0.4481 - val_root_mean_squared_error: 0.3286
# Epoch 57/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3302 - root_mean_squared_error: 0.2675 - val_loss: 0.5271 - val_root_mean_squared_error: 0.3469
# Epoch 58/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3233 - root_mean_squared_error: 0.2771 - val_loss: 0.5171 - val_root_mean_squared_error: 0.3543
# Epoch 59/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3097 - root_mean_squared_error: 0.2692 - val_loss: 0.3876 - val_root_mean_squared_error: 0.3157
# Epoch 60/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3171 - root_mean_squared_error: 0.2683 - val_loss: 0.4603 - val_root_mean_squared_error: 0.3365
# Epoch 61/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3083 - root_mean_squared_error: 0.2630 - val_loss: 0.4765 - val_root_mean_squared_error: 0.3477
# Epoch 62/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3175 - root_mean_squared_error: 0.2746 - val_loss: 0.5184 - val_root_mean_squared_error: 0.3347
# Epoch 63/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3133 - root_mean_squared_error: 0.2670 - val_loss: 0.5126 - val_root_mean_squared_error: 0.3370
# Epoch 64/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2805 - root_mean_squared_error: 0.2546 - val_loss: 0.4298 - val_root_mean_squared_error: 0.3023
# Epoch 65/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.3017 - root_mean_squared_error: 0.2619 - val_loss: 0.4274 - val_root_mean_squared_error: 0.3148
# Epoch 66/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3031 - root_mean_squared_error: 0.2619 - val_loss: 0.5175 - val_root_mean_squared_error: 0.3337
# Epoch 67/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2989 - root_mean_squared_error: 0.2624 - val_loss: 0.4684 - val_root_mean_squared_error: 0.3305
# Epoch 68/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2991 - root_mean_squared_error: 0.2603 - val_loss: 0.4008 - val_root_mean_squared_error: 0.3088
# Epoch 69/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2937 - root_mean_squared_error: 0.2578 - val_loss: 0.4983 - val_root_mean_squared_error: 0.3401
# Epoch 70/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2969 - root_mean_squared_error: 0.2563 - val_loss: 0.5571 - val_root_mean_squared_error: 0.3451
# Epoch 71/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2730 - root_mean_squared_error: 0.2548 - val_loss: 0.5188 - val_root_mean_squared_error: 0.3508
# Epoch 72/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2946 - root_mean_squared_error: 0.2519 - val_loss: 0.5075 - val_root_mean_squared_error: 0.3552
# Epoch 73/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2918 - root_mean_squared_error: 0.2588 - val_loss: 0.5476 - val_root_mean_squared_error: 0.3482
# Epoch 74/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2777 - root_mean_squared_error: 0.2459 - val_loss: 0.4195 - val_root_mean_squared_error: 0.2966
# Epoch 75/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2928 - root_mean_squared_error: 0.2566 - val_loss: 0.4813 - val_root_mean_squared_error: 0.3513
# Epoch 76/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2937 - root_mean_squared_error: 0.2580 - val_loss: 0.4790 - val_root_mean_squared_error: 0.3305
# Epoch 77/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2916 - root_mean_squared_error: 0.2513 - val_loss: 0.5922 - val_root_mean_squared_error: 0.3410
# Epoch 78/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2898 - root_mean_squared_error: 0.2602 - val_loss: 0.5269 - val_root_mean_squared_error: 0.3365
# Epoch 79/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2841 - root_mean_squared_error: 0.2539 - val_loss: 0.3845 - val_root_mean_squared_error: 0.3333
# Epoch 80/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2777 - root_mean_squared_error: 0.2421 - val_loss: 0.6433 - val_root_mean_squared_error: 0.3556
# Epoch 81/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2818 - root_mean_squared_error: 0.2527 - val_loss: 0.5065 - val_root_mean_squared_error: 0.3230
# Epoch 82/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2937 - root_mean_squared_error: 0.2527 - val_loss: 0.5332 - val_root_mean_squared_error: 0.3539
# Epoch 83/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2875 - root_mean_squared_error: 0.2534 - val_loss: 0.6642 - val_root_mean_squared_error: 0.3595
# Epoch 84/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2935 - root_mean_squared_error: 0.2505 - val_loss: 0.5019 - val_root_mean_squared_error: 0.3419
# Epoch 85/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2848 - root_mean_squared_error: 0.2533 - val_loss: 0.4011 - val_root_mean_squared_error: 0.3043
# Epoch 86/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2784 - root_mean_squared_error: 0.2419 - val_loss: 0.3657 - val_root_mean_squared_error: 0.2866
# Epoch 87/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2729 - root_mean_squared_error: 0.2510 - val_loss: 0.4359 - val_root_mean_squared_error: 0.3249
# Epoch 88/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2804 - root_mean_squared_error: 0.2522 - val_loss: 0.5549 - val_root_mean_squared_error: 0.3477
# Epoch 89/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2680 - root_mean_squared_error: 0.2407 - val_loss: 0.5239 - val_root_mean_squared_error: 0.3253
# Epoch 90/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2729 - root_mean_squared_error: 0.2387 - val_loss: 0.3470 - val_root_mean_squared_error: 0.2779
# Epoch 91/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2794 - root_mean_squared_error: 0.2454 - val_loss: 0.4044 - val_root_mean_squared_error: 0.2919
# Epoch 92/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2965 - root_mean_squared_error: 0.2540 - val_loss: 0.4427 - val_root_mean_squared_error: 0.3143
# Epoch 93/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2747 - root_mean_squared_error: 0.2485 - val_loss: 0.4899 - val_root_mean_squared_error: 0.3347
# Epoch 94/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2750 - root_mean_squared_error: 0.2493 - val_loss: 0.4752 - val_root_mean_squared_error: 0.3162
# Epoch 95/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2667 - root_mean_squared_error: 0.2435 - val_loss: 0.4073 - val_root_mean_squared_error: 0.2940
# Epoch 96/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2614 - root_mean_squared_error: 0.2386 - val_loss: 0.4280 - val_root_mean_squared_error: 0.2818
# Epoch 97/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2722 - root_mean_squared_error: 0.2435 - val_loss: 0.3918 - val_root_mean_squared_error: 0.2914
# Epoch 98/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2616 - root_mean_squared_error: 0.2397 - val_loss: 0.3618 - val_root_mean_squared_error: 0.2882
# Epoch 99/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2814 - root_mean_squared_error: 0.2456 - val_loss: 0.4910 - val_root_mean_squared_error: 0.3113
# Epoch 100/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2695 - root_mean_squared_error: 0.2431 - val_loss: 0.4892 - val_root_mean_squared_error: 0.3038
# Epoch 101/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2479 - root_mean_squared_error: 0.2335 - val_loss: 0.4729 - val_root_mean_squared_error: 0.3177
# Epoch 102/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2639 - root_mean_squared_error: 0.2358 - val_loss: 0.5500 - val_root_mean_squared_error: 0.3268
# Epoch 103/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2678 - root_mean_squared_error: 0.2339 - val_loss: 0.6507 - val_root_mean_squared_error: 0.3442
# Epoch 104/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2774 - root_mean_squared_error: 0.2408 - val_loss: 0.4177 - val_root_mean_squared_error: 0.2961
# Epoch 105/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2558 - root_mean_squared_error: 0.2347 - val_loss: 0.4860 - val_root_mean_squared_error: 0.3033
# Epoch 106/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2487 - root_mean_squared_error: 0.2299 - val_loss: 0.5667 - val_root_mean_squared_error: 0.3167
# Epoch 107/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2543 - root_mean_squared_error: 0.2292 - val_loss: 0.6545 - val_root_mean_squared_error: 0.3482
# Epoch 108/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2455 - root_mean_squared_error: 0.2240 - val_loss: 0.5065 - val_root_mean_squared_error: 0.3191
# Epoch 109/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2470 - root_mean_squared_error: 0.2290 - val_loss: 0.6096 - val_root_mean_squared_error: 0.3220
# Epoch 110/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2399 - root_mean_squared_error: 0.2198 - val_loss: 0.5321 - val_root_mean_squared_error: 0.3138
# Epoch 111/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2375 - root_mean_squared_error: 0.2224 - val_loss: 0.4817 - val_root_mean_squared_error: 0.3118
# Epoch 112/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2588 - root_mean_squared_error: 0.2322 - val_loss: 0.5262 - val_root_mean_squared_error: 0.3138
# Epoch 113/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2344 - root_mean_squared_error: 0.2175 - val_loss: 0.5042 - val_root_mean_squared_error: 0.3253
# Epoch 114/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2422 - root_mean_squared_error: 0.2154 - val_loss: 0.6563 - val_root_mean_squared_error: 0.3508
# Epoch 115/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2398 - root_mean_squared_error: 0.2152 - val_loss: 0.4476 - val_root_mean_squared_error: 0.2774
# Epoch 116/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2451 - root_mean_squared_error: 0.2290 - val_loss: 0.5769 - val_root_mean_squared_error: 0.3268
# Epoch 117/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2355 - root_mean_squared_error: 0.2187 - val_loss: 0.7442 - val_root_mean_squared_error: 0.3729
# Epoch 118/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2507 - root_mean_squared_error: 0.2219 - val_loss: 0.6520 - val_root_mean_squared_error: 0.3206
# Epoch 119/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2201 - root_mean_squared_error: 0.2120 - val_loss: 0.5611 - val_root_mean_squared_error: 0.3428
# Epoch 120/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2468 - root_mean_squared_error: 0.2187 - val_loss: 0.5109 - val_root_mean_squared_error: 0.3319
# Epoch 121/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2441 - root_mean_squared_error: 0.2224 - val_loss: 0.5157 - val_root_mean_squared_error: 0.3172
# Epoch 122/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2477 - root_mean_squared_error: 0.2243 - val_loss: 0.6507 - val_root_mean_squared_error: 0.3637
# Epoch 123/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2299 - root_mean_squared_error: 0.2112 - val_loss: 0.5076 - val_root_mean_squared_error: 0.2919
# Epoch 124/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2440 - root_mean_squared_error: 0.2246 - val_loss: 0.5034 - val_root_mean_squared_error: 0.3187
# Epoch 125/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2285 - root_mean_squared_error: 0.2105 - val_loss: 0.4726 - val_root_mean_squared_error: 0.2845
# Epoch 126/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2463 - root_mean_squared_error: 0.2236 - val_loss: 0.4237 - val_root_mean_squared_error: 0.3008
# Epoch 127/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2296 - root_mean_squared_error: 0.2175 - val_loss: 0.4876 - val_root_mean_squared_error: 0.3201
# Epoch 128/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2292 - root_mean_squared_error: 0.2112 - val_loss: 0.5420 - val_root_mean_squared_error: 0.3068
# Epoch 129/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2330 - root_mean_squared_error: 0.2066 - val_loss: 0.5954 - val_root_mean_squared_error: 0.3333
# Epoch 130/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2195 - root_mean_squared_error: 0.2090 - val_loss: 0.3947 - val_root_mean_squared_error: 0.2823
# Epoch 131/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2447 - root_mean_squared_error: 0.2212 - val_loss: 0.4538 - val_root_mean_squared_error: 0.2930
# Epoch 132/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2349 - root_mean_squared_error: 0.2163 - val_loss: 0.4597 - val_root_mean_squared_error: 0.3033
# Epoch 133/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2442 - root_mean_squared_error: 0.2215 - val_loss: 0.5378 - val_root_mean_squared_error: 0.3277
# Epoch 134/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2403 - root_mean_squared_error: 0.2221 - val_loss: 0.5888 - val_root_mean_squared_error: 0.3625
# Epoch 135/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2392 - root_mean_squared_error: 0.2219 - val_loss: 0.5557 - val_root_mean_squared_error: 0.3187
# Epoch 136/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2407 - root_mean_squared_error: 0.2175 - val_loss: 0.4885 - val_root_mean_squared_error: 0.3033
# Epoch 137/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2317 - root_mean_squared_error: 0.2164 - val_loss: 0.8400 - val_root_mean_squared_error: 0.4023
# Epoch 138/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2422 - root_mean_squared_error: 0.2130 - val_loss: 0.5805 - val_root_mean_squared_error: 0.3508
# Epoch 139/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2319 - root_mean_squared_error: 0.2121 - val_loss: 0.5836 - val_root_mean_squared_error: 0.3196
# Epoch 140/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2263 - root_mean_squared_error: 0.2125 - val_loss: 0.5531 - val_root_mean_squared_error: 0.3206
# Epoch 141/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2279 - root_mean_squared_error: 0.2121 - val_loss: 0.5337 - val_root_mean_squared_error: 0.3379
# Epoch 142/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2312 - root_mean_squared_error: 0.2055 - val_loss: 0.4770 - val_root_mean_squared_error: 0.2855
# Epoch 143/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2328 - root_mean_squared_error: 0.2203 - val_loss: 0.4659 - val_root_mean_squared_error: 0.3123
# Epoch 144/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2104 - root_mean_squared_error: 0.2034 - val_loss: 0.5514 - val_root_mean_squared_error: 0.3356
# Epoch 145/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2311 - root_mean_squared_error: 0.2163 - val_loss: 0.7140 - val_root_mean_squared_error: 0.3637
# Epoch 146/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2281 - root_mean_squared_error: 0.2150 - val_loss: 0.4689 - val_root_mean_squared_error: 0.3201
# Epoch 147/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2237 - root_mean_squared_error: 0.2094 - val_loss: 0.5205 - val_root_mean_squared_error: 0.3225
# Epoch 148/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2024 - root_mean_squared_error: 0.1981 - val_loss: 0.8474 - val_root_mean_squared_error: 0.3807
# Epoch 149/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2042 - root_mean_squared_error: 0.2004 - val_loss: 0.4059 - val_root_mean_squared_error: 0.2631
# Epoch 150/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2274 - root_mean_squared_error: 0.2148 - val_loss: 0.5250 - val_root_mean_squared_error: 0.2904
# Epoch 151/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2302 - root_mean_squared_error: 0.2136 - val_loss: 0.5787 - val_root_mean_squared_error: 0.3196
# Epoch 152/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2260 - root_mean_squared_error: 0.2090 - val_loss: 0.5382 - val_root_mean_squared_error: 0.3172
# Epoch 153/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2307 - root_mean_squared_error: 0.2059 - val_loss: 0.5042 - val_root_mean_squared_error: 0.2961
# Epoch 154/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2283 - root_mean_squared_error: 0.2098 - val_loss: 0.7779 - val_root_mean_squared_error: 0.3582
# Epoch 155/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2173 - root_mean_squared_error: 0.2012 - val_loss: 0.4341 - val_root_mean_squared_error: 0.3118
# Epoch 156/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2265 - root_mean_squared_error: 0.2094 - val_loss: 0.5316 - val_root_mean_squared_error: 0.3153
# Epoch 157/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2343 - root_mean_squared_error: 0.2109 - val_loss: 0.7150 - val_root_mean_squared_error: 0.3582
# Epoch 158/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2369 - root_mean_squared_error: 0.2208 - val_loss: 0.6448 - val_root_mean_squared_error: 0.3319
# Epoch 159/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2243 - root_mean_squared_error: 0.2130 - val_loss: 0.5647 - val_root_mean_squared_error: 0.3013
# Epoch 160/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2248 - root_mean_squared_error: 0.2103 - val_loss: 0.3479 - val_root_mean_squared_error: 0.2456
# Epoch 161/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2230 - root_mean_squared_error: 0.2175 - val_loss: 0.5580 - val_root_mean_squared_error: 0.2909
# Epoch 162/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2080 - root_mean_squared_error: 0.2083 - val_loss: 0.4955 - val_root_mean_squared_error: 0.2850
# Epoch 163/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2222 - root_mean_squared_error: 0.2038 - val_loss: 0.7532 - val_root_mean_squared_error: 0.3688
# Epoch 164/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2280 - root_mean_squared_error: 0.2107 - val_loss: 0.7182 - val_root_mean_squared_error: 0.3442
# Epoch 165/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2171 - root_mean_squared_error: 0.2120 - val_loss: 0.3965 - val_root_mean_squared_error: 0.2919
# Epoch 166/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2303 - root_mean_squared_error: 0.2105 - val_loss: 0.5705 - val_root_mean_squared_error: 0.3328
# Epoch 167/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2246 - root_mean_squared_error: 0.2168 - val_loss: 0.5526 - val_root_mean_squared_error: 0.3058
# Epoch 168/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2217 - root_mean_squared_error: 0.2062 - val_loss: 0.5198 - val_root_mean_squared_error: 0.3033
# Epoch 169/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2261 - root_mean_squared_error: 0.2079 - val_loss: 0.7625 - val_root_mean_squared_error: 0.3843
# Epoch 170/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2177 - root_mean_squared_error: 0.2049 - val_loss: 0.6692 - val_root_mean_squared_error: 0.3406
# Epoch 171/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2269 - root_mean_squared_error: 0.2163 - val_loss: 0.3238 - val_root_mean_squared_error: 0.2320
# Epoch 172/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2033 - root_mean_squared_error: 0.1975 - val_loss: 0.6789 - val_root_mean_squared_error: 0.3578
# Epoch 173/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2139 - root_mean_squared_error: 0.2057 - val_loss: 0.8348 - val_root_mean_squared_error: 0.3625
# Epoch 174/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2074 - root_mean_squared_error: 0.1975 - val_loss: 0.5067 - val_root_mean_squared_error: 0.3083
# Epoch 175/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2363 - root_mean_squared_error: 0.2217 - val_loss: 0.5430 - val_root_mean_squared_error: 0.3225
# Epoch 176/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2104 - root_mean_squared_error: 0.2038 - val_loss: 0.3850 - val_root_mean_squared_error: 0.2746
# Epoch 177/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2113 - root_mean_squared_error: 0.2000 - val_loss: 0.5870 - val_root_mean_squared_error: 0.3347
# Epoch 178/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2142 - root_mean_squared_error: 0.1990 - val_loss: 0.4012 - val_root_mean_squared_error: 0.2660
# Epoch 179/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2186 - root_mean_squared_error: 0.2085 - val_loss: 0.5167 - val_root_mean_squared_error: 0.2914
# Epoch 180/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2215 - root_mean_squared_error: 0.2121 - val_loss: 0.4868 - val_root_mean_squared_error: 0.2672
# Epoch 181/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2087 - root_mean_squared_error: 0.2015 - val_loss: 0.5372 - val_root_mean_squared_error: 0.2845
# Epoch 182/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2099 - root_mean_squared_error: 0.1955 - val_loss: 0.7964 - val_root_mean_squared_error: 0.3646
# Epoch 183/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2155 - root_mean_squared_error: 0.1965 - val_loss: 0.4082 - val_root_mean_squared_error: 0.2757
# Epoch 184/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2343 - root_mean_squared_error: 0.2087 - val_loss: 0.6905 - val_root_mean_squared_error: 0.3324
# Epoch 185/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2148 - root_mean_squared_error: 0.2025 - val_loss: 0.5195 - val_root_mean_squared_error: 0.2966
# Epoch 186/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1985 - root_mean_squared_error: 0.1963 - val_loss: 0.4742 - val_root_mean_squared_error: 0.3053
# Epoch 187/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2148 - root_mean_squared_error: 0.2057 - val_loss: 0.3617 - val_root_mean_squared_error: 0.2340
# Epoch 188/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2081 - root_mean_squared_error: 0.2006 - val_loss: 0.6128 - val_root_mean_squared_error: 0.3272
# Epoch 189/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1820 - root_mean_squared_error: 0.1875 - val_loss: 0.8118 - val_root_mean_squared_error: 0.3424
# Epoch 190/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2158 - root_mean_squared_error: 0.2008 - val_loss: 0.7217 - val_root_mean_squared_error: 0.3314
# Epoch 191/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2078 - root_mean_squared_error: 0.2015 - val_loss: 0.7553 - val_root_mean_squared_error: 0.3599
# Epoch 192/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2056 - root_mean_squared_error: 0.2077 - val_loss: 0.5044 - val_root_mean_squared_error: 0.3028
# Epoch 193/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2317 - root_mean_squared_error: 0.2032 - val_loss: 0.7479 - val_root_mean_squared_error: 0.3451
# Epoch 194/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1972 - root_mean_squared_error: 0.1926 - val_loss: 0.6113 - val_root_mean_squared_error: 0.3113
# Epoch 195/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2260 - root_mean_squared_error: 0.2053 - val_loss: 0.5050 - val_root_mean_squared_error: 0.2729
# Epoch 196/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1932 - root_mean_squared_error: 0.1937 - val_loss: 0.4951 - val_root_mean_squared_error: 0.3118
# Epoch 197/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1951 - root_mean_squared_error: 0.1969 - val_loss: 0.6643 - val_root_mean_squared_error: 0.3392
# Epoch 198/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2015 - root_mean_squared_error: 0.1945 - val_loss: 0.5338 - val_root_mean_squared_error: 0.2946
# Epoch 199/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2002 - root_mean_squared_error: 0.1937 - val_loss: 0.7039 - val_root_mean_squared_error: 0.3337
# Epoch 200/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1928 - root_mean_squared_error: 0.1885 - val_loss: 0.4855 - val_root_mean_squared_error: 0.2914
# Epoch 201/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1985 - root_mean_squared_error: 0.1907 - val_loss: 0.5080 - val_root_mean_squared_error: 0.3023
# Epoch 202/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1962 - root_mean_squared_error: 0.1893 - val_loss: 0.6046 - val_root_mean_squared_error: 0.3495
# Epoch 203/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1868 - root_mean_squared_error: 0.1885 - val_loss: 0.7090 - val_root_mean_squared_error: 0.3191
# Epoch 204/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2036 - root_mean_squared_error: 0.1901 - val_loss: 0.4717 - val_root_mean_squared_error: 0.2866
# Epoch 205/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2116 - root_mean_squared_error: 0.2000 - val_loss: 0.7922 - val_root_mean_squared_error: 0.3328
# Epoch 206/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1869 - root_mean_squared_error: 0.1920 - val_loss: 0.7262 - val_root_mean_squared_error: 0.3337
# Epoch 207/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2116 - root_mean_squared_error: 0.1963 - val_loss: 0.8181 - val_root_mean_squared_error: 0.3556
# Epoch 208/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1782 - root_mean_squared_error: 0.1814 - val_loss: 0.8197 - val_root_mean_squared_error: 0.3667
# Epoch 209/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1868 - root_mean_squared_error: 0.1881 - val_loss: 0.6319 - val_root_mean_squared_error: 0.3018
# Epoch 210/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2101 - root_mean_squared_error: 0.1998 - val_loss: 0.6323 - val_root_mean_squared_error: 0.3328
# Epoch 211/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1799 - root_mean_squared_error: 0.1883 - val_loss: 0.4890 - val_root_mean_squared_error: 0.2834
# Epoch 212/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.2098 - root_mean_squared_error: 0.1897 - val_loss: 0.8008 - val_root_mean_squared_error: 0.3633
# Epoch 213/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1957 - root_mean_squared_error: 0.1869 - val_loss: 0.5116 - val_root_mean_squared_error: 0.3048
# Epoch 214/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1855 - root_mean_squared_error: 0.1912 - val_loss: 0.4951 - val_root_mean_squared_error: 0.2818
# Epoch 215/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2106 - root_mean_squared_error: 0.1932 - val_loss: 0.6281 - val_root_mean_squared_error: 0.3118
# Epoch 216/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1846 - root_mean_squared_error: 0.1814 - val_loss: 0.5385 - val_root_mean_squared_error: 0.3113
# Epoch 217/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1984 - root_mean_squared_error: 0.1920 - val_loss: 0.8492 - val_root_mean_squared_error: 0.3696
# Epoch 218/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1928 - root_mean_squared_error: 0.1869 - val_loss: 0.6994 - val_root_mean_squared_error: 0.3234
# Epoch 219/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1700 - root_mean_squared_error: 0.1873 - val_loss: 0.5817 - val_root_mean_squared_error: 0.3113
# Epoch 220/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1765 - root_mean_squared_error: 0.1800 - val_loss: 0.5849 - val_root_mean_squared_error: 0.3370
# Epoch 221/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1908 - root_mean_squared_error: 0.1814 - val_loss: 0.5010 - val_root_mean_squared_error: 0.2456
# Epoch 222/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1618 - root_mean_squared_error: 0.1772 - val_loss: 0.6986 - val_root_mean_squared_error: 0.3162
# Epoch 223/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1626 - root_mean_squared_error: 0.1721 - val_loss: 0.7333 - val_root_mean_squared_error: 0.3201
# Epoch 224/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1740 - root_mean_squared_error: 0.1758 - val_loss: 0.9762 - val_root_mean_squared_error: 0.3815
# Epoch 225/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1666 - root_mean_squared_error: 0.1705 - val_loss: 0.5615 - val_root_mean_squared_error: 0.3003
# Epoch 226/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1687 - root_mean_squared_error: 0.1761 - val_loss: 0.6306 - val_root_mean_squared_error: 0.3253
# Epoch 227/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1819 - root_mean_squared_error: 0.1736 - val_loss: 0.5892 - val_root_mean_squared_error: 0.2982
# Epoch 228/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1753 - root_mean_squared_error: 0.1739 - val_loss: 0.8332 - val_root_mean_squared_error: 0.3646
# Epoch 229/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1790 - root_mean_squared_error: 0.1791 - val_loss: 0.5133 - val_root_mean_squared_error: 0.2834
# Epoch 230/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1701 - root_mean_squared_error: 0.1736 - val_loss: 0.6742 - val_root_mean_squared_error: 0.3337
# Epoch 231/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1990 - root_mean_squared_error: 0.1867 - val_loss: 0.6997 - val_root_mean_squared_error: 0.3437
# Epoch 232/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1944 - root_mean_squared_error: 0.1879 - val_loss: 0.5989 - val_root_mean_squared_error: 0.3410
# Epoch 233/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1759 - root_mean_squared_error: 0.1763 - val_loss: 0.6733 - val_root_mean_squared_error: 0.2845
# Epoch 234/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1914 - root_mean_squared_error: 0.1877 - val_loss: 0.7251 - val_root_mean_squared_error: 0.3300
# Epoch 235/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1659 - root_mean_squared_error: 0.1739 - val_loss: 0.6735 - val_root_mean_squared_error: 0.3162
# Epoch 236/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1652 - root_mean_squared_error: 0.1728 - val_loss: 0.5948 - val_root_mean_squared_error: 0.3220
# Epoch 237/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1774 - root_mean_squared_error: 0.1761 - val_loss: 0.5624 - val_root_mean_squared_error: 0.3023
# Epoch 238/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1929 - root_mean_squared_error: 0.1831 - val_loss: 0.5593 - val_root_mean_squared_error: 0.2746
# Epoch 239/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1872 - root_mean_squared_error: 0.1856 - val_loss: 0.7212 - val_root_mean_squared_error: 0.3324
# Epoch 240/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1765 - root_mean_squared_error: 0.1806 - val_loss: 0.9503 - val_root_mean_squared_error: 0.3754
# Epoch 241/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1550 - root_mean_squared_error: 0.1712 - val_loss: 0.5362 - val_root_mean_squared_error: 0.2861
# Epoch 242/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1686 - root_mean_squared_error: 0.1643 - val_loss: 0.7794 - val_root_mean_squared_error: 0.3469
# Epoch 243/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1685 - root_mean_squared_error: 0.1641 - val_loss: 0.7290 - val_root_mean_squared_error: 0.3220
# Epoch 244/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1546 - root_mean_squared_error: 0.1662 - val_loss: 0.5549 - val_root_mean_squared_error: 0.2468
# Epoch 245/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1596 - root_mean_squared_error: 0.1689 - val_loss: 0.7130 - val_root_mean_squared_error: 0.3211
# Epoch 246/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1662 - root_mean_squared_error: 0.1673 - val_loss: 0.5377 - val_root_mean_squared_error: 0.2834
# Epoch 247/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1840 - root_mean_squared_error: 0.1772 - val_loss: 0.3844 - val_root_mean_squared_error: 0.2431
# Epoch 248/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1798 - root_mean_squared_error: 0.1758 - val_loss: 0.8706 - val_root_mean_squared_error: 0.3899
# Epoch 249/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1693 - root_mean_squared_error: 0.1638 - val_loss: 0.7503 - val_root_mean_squared_error: 0.3654
# Epoch 250/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1672 - root_mean_squared_error: 0.1769 - val_loss: 0.6059 - val_root_mean_squared_error: 0.3113
# Epoch 251/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1518 - root_mean_squared_error: 0.1605 - val_loss: 0.5020 - val_root_mean_squared_error: 0.2602
# Epoch 252/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1709 - root_mean_squared_error: 0.1705 - val_loss: 0.6465 - val_root_mean_squared_error: 0.2866
# Epoch 253/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1644 - root_mean_squared_error: 0.1692 - val_loss: 0.5964 - val_root_mean_squared_error: 0.2992
# Epoch 254/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1694 - root_mean_squared_error: 0.1678 - val_loss: 0.5677 - val_root_mean_squared_error: 0.2850
# Epoch 255/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1647 - root_mean_squared_error: 0.1636 - val_loss: 0.9083 - val_root_mean_squared_error: 0.3654
# Epoch 256/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1623 - root_mean_squared_error: 0.1627 - val_loss: 0.6144 - val_root_mean_squared_error: 0.2904
# Epoch 257/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1725 - root_mean_squared_error: 0.1774 - val_loss: 1.0371 - val_root_mean_squared_error: 0.3268
# Epoch 258/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1547 - root_mean_squared_error: 0.1579 - val_loss: 0.5851 - val_root_mean_squared_error: 0.2660
# Epoch 259/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1701 - root_mean_squared_error: 0.1664 - val_loss: 0.7769 - val_root_mean_squared_error: 0.3401
# Epoch 260/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1621 - root_mean_squared_error: 0.1678 - val_loss: 0.9231 - val_root_mean_squared_error: 0.3392
# Epoch 261/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1514 - root_mean_squared_error: 0.1638 - val_loss: 0.6866 - val_root_mean_squared_error: 0.3455
# Epoch 262/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1729 - root_mean_squared_error: 0.1671 - val_loss: 0.6174 - val_root_mean_squared_error: 0.3033
# Epoch 263/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1464 - root_mean_squared_error: 0.1571 - val_loss: 1.1084 - val_root_mean_squared_error: 0.3733
# Epoch 264/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1768 - root_mean_squared_error: 0.1646 - val_loss: 0.5928 - val_root_mean_squared_error: 0.2807
# Epoch 265/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1439 - root_mean_squared_error: 0.1411 - val_loss: 1.0513 - val_root_mean_squared_error: 0.3521
# Epoch 266/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1697 - root_mean_squared_error: 0.1664 - val_loss: 0.9554 - val_root_mean_squared_error: 0.3754
# Epoch 267/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1521 - root_mean_squared_error: 0.1620 - val_loss: 0.6355 - val_root_mean_squared_error: 0.3191
# Epoch 268/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1705 - root_mean_squared_error: 0.1657 - val_loss: 0.6547 - val_root_mean_squared_error: 0.3018
# Epoch 269/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1514 - root_mean_squared_error: 0.1564 - val_loss: 0.9166 - val_root_mean_squared_error: 0.3187
# Epoch 270/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1495 - root_mean_squared_error: 0.1622 - val_loss: 0.4844 - val_root_mean_squared_error: 0.2982
# Epoch 271/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1673 - root_mean_squared_error: 0.1659 - val_loss: 0.7714 - val_root_mean_squared_error: 0.3337
# Epoch 272/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1476 - root_mean_squared_error: 0.1519 - val_loss: 0.8136 - val_root_mean_squared_error: 0.3437
# Epoch 273/500
# 51/51 [==============================] - 0s 6ms/step - loss: 0.1486 - root_mean_squared_error: 0.1617 - val_loss: 1.1238 - val_root_mean_squared_error: 0.3922
# Epoch 274/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1617 - root_mean_squared_error: 0.1741 - val_loss: 1.1707 - val_root_mean_squared_error: 0.3762
# Epoch 275/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1785 - root_mean_squared_error: 0.1705 - val_loss: 0.5666 - val_root_mean_squared_error: 0.2596
# Epoch 276/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1513 - root_mean_squared_error: 0.1544 - val_loss: 0.7614 - val_root_mean_squared_error: 0.2951
# Epoch 277/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1616 - root_mean_squared_error: 0.1615 - val_loss: 0.7790 - val_root_mean_squared_error: 0.3365
# Epoch 278/500
# 51/51 [==============================] - 1s 10ms/step - loss: 0.1598 - root_mean_squared_error: 0.1581 - val_loss: 0.6856 - val_root_mean_squared_error: 0.3314
# ...
# Epoch 409/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3343 - root_mean_squared_error: 0.2568 - val_loss: 0.5133 - val_root_mean_squared_error: 0.3517
# Epoch 410/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3291 - root_mean_squared_error: 0.2557 - val_loss: 0.7160 - val_root_mean_squared_error: 0.3787
# Epoch 411/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3272 - root_mean_squared_error: 0.2590 - val_loss: 0.5785 - val_root_mean_squared_error: 0.3424
# Epoch 412/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3231 - root_mean_squared_error: 0.2485 - val_loss: 0.5112 - val_root_mean_squared_error: 0.3272
# Epoch 413/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3344 - root_mean_squared_error: 0.2557 - val_loss: 0.7599 - val_root_mean_squared_error: 0.3742
# Epoch 414/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3162 - root_mean_squared_error: 0.2504 - val_loss: 0.7346 - val_root_mean_squared_error: 0.3663
# Epoch 415/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3071 - root_mean_squared_error: 0.2562 - val_loss: 0.4579 - val_root_mean_squared_error: 0.3003
# Epoch 416/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3043 - root_mean_squared_error: 0.2559 - val_loss: 0.8740 - val_root_mean_squared_error: 0.4214
# Epoch 417/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3109 - root_mean_squared_error: 0.2556 - val_loss: 0.7202 - val_root_mean_squared_error: 0.3942
# Epoch 418/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3147 - root_mean_squared_error: 0.2504 - val_loss: 0.7179 - val_root_mean_squared_error: 0.3625
# Epoch 419/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3609 - root_mean_squared_error: 0.2678 - val_loss: 0.5822 - val_root_mean_squared_error: 0.3603
# Epoch 420/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3270 - root_mean_squared_error: 0.2569 - val_loss: 0.7446 - val_root_mean_squared_error: 0.3675
# Epoch 421/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3261 - root_mean_squared_error: 0.2550 - val_loss: 0.6400 - val_root_mean_squared_error: 0.3560
# Epoch 422/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2968 - root_mean_squared_error: 0.2465 - val_loss: 0.6132 - val_root_mean_squared_error: 0.3903
# Epoch 423/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2996 - root_mean_squared_error: 0.2498 - val_loss: 0.5407 - val_root_mean_squared_error: 0.2940
# Epoch 424/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3024 - root_mean_squared_error: 0.2443 - val_loss: 0.8499 - val_root_mean_squared_error: 0.3981
# Epoch 425/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3386 - root_mean_squared_error: 0.2649 - val_loss: 0.5029 - val_root_mean_squared_error: 0.3633
# Epoch 426/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3065 - root_mean_squared_error: 0.2562 - val_loss: 0.6629 - val_root_mean_squared_error: 0.3415
# Epoch 427/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3521 - root_mean_squared_error: 0.2660 - val_loss: 0.6380 - val_root_mean_squared_error: 0.3560
# Epoch 428/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3166 - root_mean_squared_error: 0.2554 - val_loss: 0.4883 - val_root_mean_squared_error: 0.3234
# Epoch 429/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3397 - root_mean_squared_error: 0.2641 - val_loss: 0.6801 - val_root_mean_squared_error: 0.3608
# Epoch 430/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3424 - root_mean_squared_error: 0.2580 - val_loss: 0.6087 - val_root_mean_squared_error: 0.3725
# Epoch 431/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3348 - root_mean_squared_error: 0.2606 - val_loss: 0.7250 - val_root_mean_squared_error: 0.3996
# Epoch 432/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2983 - root_mean_squared_error: 0.2449 - val_loss: 0.5928 - val_root_mean_squared_error: 0.3486
# Epoch 433/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2968 - root_mean_squared_error: 0.2508 - val_loss: 0.8948 - val_root_mean_squared_error: 0.4118
# Epoch 434/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3064 - root_mean_squared_error: 0.2467 - val_loss: 0.5556 - val_root_mean_squared_error: 0.3314
# Epoch 435/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3242 - root_mean_squared_error: 0.2584 - val_loss: 0.5186 - val_root_mean_squared_error: 0.3291
# Epoch 436/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3259 - root_mean_squared_error: 0.2502 - val_loss: 0.5228 - val_root_mean_squared_error: 0.3305
# Epoch 437/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3096 - root_mean_squared_error: 0.2528 - val_loss: 0.5590 - val_root_mean_squared_error: 0.3419
# Epoch 438/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3147 - root_mean_squared_error: 0.2581 - val_loss: 0.7389 - val_root_mean_squared_error: 0.3543
# Epoch 439/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3166 - root_mean_squared_error: 0.2588 - val_loss: 0.9881 - val_root_mean_squared_error: 0.3879
# Epoch 440/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3011 - root_mean_squared_error: 0.2510 - val_loss: 0.5805 - val_root_mean_squared_error: 0.3053
# Epoch 441/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3123 - root_mean_squared_error: 0.2518 - val_loss: 0.6200 - val_root_mean_squared_error: 0.3220
# Epoch 442/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3156 - root_mean_squared_error: 0.2485 - val_loss: 0.5324 - val_root_mean_squared_error: 0.3310
# Epoch 443/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3134 - root_mean_squared_error: 0.2539 - val_loss: 0.6191 - val_root_mean_squared_error: 0.3791
# Epoch 444/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2996 - root_mean_squared_error: 0.2448 - val_loss: 0.5398 - val_root_mean_squared_error: 0.3582
# Epoch 445/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3145 - root_mean_squared_error: 0.2459 - val_loss: 0.7901 - val_root_mean_squared_error: 0.3663
# Epoch 446/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3180 - root_mean_squared_error: 0.2609 - val_loss: 0.6835 - val_root_mean_squared_error: 0.3847
# Epoch 447/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3440 - root_mean_squared_error: 0.2640 - val_loss: 0.8126 - val_root_mean_squared_error: 0.3560
# Epoch 448/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3064 - root_mean_squared_error: 0.2495 - val_loss: 0.4636 - val_root_mean_squared_error: 0.3143
# Epoch 449/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3525 - root_mean_squared_error: 0.2646 - val_loss: 0.5043 - val_root_mean_squared_error: 0.3187
# Epoch 450/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3347 - root_mean_squared_error: 0.2662 - val_loss: 0.5153 - val_root_mean_squared_error: 0.3599
# Epoch 451/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3030 - root_mean_squared_error: 0.2575 - val_loss: 0.5588 - val_root_mean_squared_error: 0.3709
# Epoch 452/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3214 - root_mean_squared_error: 0.2498 - val_loss: 0.7599 - val_root_mean_squared_error: 0.3534
# Epoch 453/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3370 - root_mean_squared_error: 0.2614 - val_loss: 0.6508 - val_root_mean_squared_error: 0.3083
# Epoch 454/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3259 - root_mean_squared_error: 0.2499 - val_loss: 0.5264 - val_root_mean_squared_error: 0.3328
# Epoch 455/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3004 - root_mean_squared_error: 0.2456 - val_loss: 0.6109 - val_root_mean_squared_error: 0.3415
# Epoch 456/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3279 - root_mean_squared_error: 0.2505 - val_loss: 0.6560 - val_root_mean_squared_error: 0.3684
# Epoch 457/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3218 - root_mean_squared_error: 0.2550 - val_loss: 0.4929 - val_root_mean_squared_error: 0.3182
# Epoch 458/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3184 - root_mean_squared_error: 0.2482 - val_loss: 0.5298 - val_root_mean_squared_error: 0.3319
# Epoch 459/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3130 - root_mean_squared_error: 0.2513 - val_loss: 0.7505 - val_root_mean_squared_error: 0.3612
# Epoch 460/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3350 - root_mean_squared_error: 0.2608 - val_loss: 0.8204 - val_root_mean_squared_error: 0.3725
# Epoch 461/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3245 - root_mean_squared_error: 0.2578 - val_loss: 0.8760 - val_root_mean_squared_error: 0.3977
# Epoch 462/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2934 - root_mean_squared_error: 0.2501 - val_loss: 0.4613 - val_root_mean_squared_error: 0.3113
# Epoch 463/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3324 - root_mean_squared_error: 0.2485 - val_loss: 0.7102 - val_root_mean_squared_error: 0.3300
# Epoch 464/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3317 - root_mean_squared_error: 0.2606 - val_loss: 0.6625 - val_root_mean_squared_error: 0.3374
# Epoch 465/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3457 - root_mean_squared_error: 0.2587 - val_loss: 0.5431 - val_root_mean_squared_error: 0.3379
# Epoch 466/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3472 - root_mean_squared_error: 0.2636 - val_loss: 0.4442 - val_root_mean_squared_error: 0.3191
# Epoch 467/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2987 - root_mean_squared_error: 0.2457 - val_loss: 0.6827 - val_root_mean_squared_error: 0.3831
# Epoch 468/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3243 - root_mean_squared_error: 0.2594 - val_loss: 0.6130 - val_root_mean_squared_error: 0.3451
# Epoch 469/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3319 - root_mean_squared_error: 0.2699 - val_loss: 0.8686 - val_root_mean_squared_error: 0.4004
# Epoch 470/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3074 - root_mean_squared_error: 0.2536 - val_loss: 0.4687 - val_root_mean_squared_error: 0.3172
# Epoch 471/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3140 - root_mean_squared_error: 0.2543 - val_loss: 0.5495 - val_root_mean_squared_error: 0.3482
# Epoch 472/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3136 - root_mean_squared_error: 0.2516 - val_loss: 0.8406 - val_root_mean_squared_error: 0.3469
# Epoch 473/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3287 - root_mean_squared_error: 0.2631 - val_loss: 0.5122 - val_root_mean_squared_error: 0.3058
# Epoch 474/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3160 - root_mean_squared_error: 0.2488 - val_loss: 0.4790 - val_root_mean_squared_error: 0.3324
# Epoch 475/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3030 - root_mean_squared_error: 0.2470 - val_loss: 0.6029 - val_root_mean_squared_error: 0.3370
# Epoch 476/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3219 - root_mean_squared_error: 0.2481 - val_loss: 0.5633 - val_root_mean_squared_error: 0.3451
# Epoch 477/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3008 - root_mean_squared_error: 0.2488 - val_loss: 0.4513 - val_root_mean_squared_error: 0.3008
# Epoch 478/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3079 - root_mean_squared_error: 0.2440 - val_loss: 0.5229 - val_root_mean_squared_error: 0.3406
# Epoch 479/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3397 - root_mean_squared_error: 0.2662 - val_loss: 0.4866 - val_root_mean_squared_error: 0.3211
# Epoch 480/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3183 - root_mean_squared_error: 0.2603 - val_loss: 0.6657 - val_root_mean_squared_error: 0.3191
# Epoch 481/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3172 - root_mean_squared_error: 0.2550 - val_loss: 0.7444 - val_root_mean_squared_error: 0.3379
# Epoch 482/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3186 - root_mean_squared_error: 0.2515 - val_loss: 0.6484 - val_root_mean_squared_error: 0.3725
# Epoch 483/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3045 - root_mean_squared_error: 0.2508 - val_loss: 0.7334 - val_root_mean_squared_error: 0.3296
# Epoch 484/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3410 - root_mean_squared_error: 0.2542 - val_loss: 0.6811 - val_root_mean_squared_error: 0.3442
# Epoch 485/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3259 - root_mean_squared_error: 0.2597 - val_loss: 0.6939 - val_root_mean_squared_error: 0.3930
# Epoch 486/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3168 - root_mean_squared_error: 0.2636 - val_loss: 0.4019 - val_root_mean_squared_error: 0.2672
# Epoch 487/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3191 - root_mean_squared_error: 0.2507 - val_loss: 0.7033 - val_root_mean_squared_error: 0.3305
# Epoch 488/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3157 - root_mean_squared_error: 0.2462 - val_loss: 0.5022 - val_root_mean_squared_error: 0.2992
# Epoch 489/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3161 - root_mean_squared_error: 0.2550 - val_loss: 0.6251 - val_root_mean_squared_error: 0.3392
# Epoch 490/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3017 - root_mean_squared_error: 0.2525 - val_loss: 0.5025 - val_root_mean_squared_error: 0.3191
# Epoch 491/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3247 - root_mean_squared_error: 0.2622 - val_loss: 0.5679 - val_root_mean_squared_error: 0.3688
# Epoch 492/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3205 - root_mean_squared_error: 0.2557 - val_loss: 0.6033 - val_root_mean_squared_error: 0.3406
# Epoch 493/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3343 - root_mean_squared_error: 0.2590 - val_loss: 0.5150 - val_root_mean_squared_error: 0.3342
# Epoch 494/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3156 - root_mean_squared_error: 0.2569 - val_loss: 0.6201 - val_root_mean_squared_error: 0.3415
# Epoch 495/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3116 - root_mean_squared_error: 0.2471 - val_loss: 0.6593 - val_root_mean_squared_error: 0.3725
# Epoch 496/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3163 - root_mean_squared_error: 0.2636 - val_loss: 0.8141 - val_root_mean_squared_error: 0.3646
# Epoch 497/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3544 - root_mean_squared_error: 0.2637 - val_loss: 0.8047 - val_root_mean_squared_error: 0.3992
# Epoch 498/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3514 - root_mean_squared_error: 0.2682 - val_loss: 0.5656 - val_root_mean_squared_error: 0.3799
# Epoch 499/500
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3478 - root_mean_squared_error: 0.2765 - val_loss: 0.5612 - val_root_mean_squared_error: 0.3406
# Epoch 500/500
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3259 - root_mean_squared_error: 0.2575 - val_loss: 0.7624 - val_root_mean_squared_error: 0.3374

# %%
# Prediction on test and train data with NN models
for k in params.keys():
    print('Model: %s' % (k))
    model = params[k]['model']

    params[k]['train_pd'] = model.predict(x_train, verbose = 1)
    params[k]['test_pd'] = model.predict(x_test, verbose = 1)
# Out:
# Model: bnn_a1
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_a2
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_b1
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_b2
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step

# %%
# Calculate prediction means and stddevs
for k in params.keys():
    params[k]['train_means'] = np.array([np.mean(x) for x in params[k]['train_pd']])
    params[k]['train_stdev'] = np.array([np.std(x) for x in params[k]['train_pd']])
    params[k]['test_means'] = np.array([np.mean(x) for x in params[k]['test_pd']])
    params[k]['test_stdev'] = np.array([np.std(x) for x in params[k]['test_pd']])

# %%
# Calculate test, train RMSE
for k in params.keys():
    params[k]['RMSE_train'] = mean_squared_error(y_train, params[k]['train_means'], squared = False)
    params[k]['RMSE_test'] = mean_squared_error(y_test, params[k]['test_means'], squared = False)

# %%
# Average deviations
for k in params.keys():
    params[k]['avg_train_stdev'] = params[k]['train_stdev'].mean()
    params[k]['avg_test_stdev'] = params[k]['test_stdev'].mean()

# %%
# Metrics

for k in params.keys():
    print('Model: %s' % (params[k]['label']))
    print('\tTrain RMSE: %f' % params[k]['RMSE_train'])
    print('\tTest RMSE: %f' % params[k]['RMSE_test'])
    print('\tAvg Test StDev: %f' % params[k]['avg_train_stdev'])
    print('\tAvg Train StDev: %f' % params[k]['avg_test_stdev'])
# Out:
# Model: BNN A - lr=5e-3
# 	Train RMSE: 0.090511
# 	Test RMSE: 0.323205
# 	Avg Test StDev: 0.006846
# 	Avg Train StDev: 0.019385
# Model: BNN A - lr=1e-2
# 	Train RMSE: 0.205408
# 	Test RMSE: 0.341039
# 	Avg Test StDev: 0.026846
# 	Avg Train StDev: 0.076308
# Model: BNN B - lr=5e-3
# 	Train RMSE: 0.153923
# 	Test RMSE: 0.313295
# 	Avg Test StDev: 0.018154
# 	Avg Train StDev: 0.040000
# Model: BNN B - lr=1e-2
# 	Train RMSE: 0.215103
# 	Test RMSE: 0.330501
# 	Avg Test StDev: 0.031615
# 	Avg Train StDev: 0.057231

# %%
# Plot training loss by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(1, 0, 9))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['loss'], color = colors[i], label = params[k]['label'], alpha = 0.8)
    i += 1
    
#plt.xscale('log')
plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Epoches', fontsize = 12)
plt.ylabel('Loss (-log likelihood)', fontsize = 12)
plt.title('Training Loss By Epoch', fontsize = 18)

plt.show()

# %%
# Plot training error by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(1, 0, 9))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['root_mean_squared_error'], color = colors[i], label = params[k]['label'], alpha = 0.8)
    i += 1
    
plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Epoches', fontsize = 12)
plt.ylabel('Error (RMSE)', fontsize = 12)
plt.title('Training Error By Epoch', fontsize = 18)

plt.show()

# %%
# Plot validation loss by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(1, 0, 9))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['val_loss'], color = colors[i], label = params[k]['label'], alpha = 0.8)
    i += 1
    
plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Epoches', fontsize = 12)
plt.ylabel('Loss (-log likelihood)', fontsize = 12)
plt.title('Validation Loss By Epoch', fontsize = 18)

plt.show()

# %%
# Plot validation error by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(1, 0, 9))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['val_root_mean_squared_error'], color = colors[i], label = params[k]['label'], alpha = 0.8)
    i += 1
    
plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Epoches', fontsize = 12)
plt.ylabel('Error (RMSE)', fontsize = 12)
plt.title('Validation Error By Epoch', fontsize = 18)

plt.show()

# %%
# Plot distributions
fig, ax = plt.subplots(2, 2, figsize = (30, 12), dpi = 100)
colors = pl.cm.jet(np.linspace(1, 0, 8))
c = 0

k = list(params.keys())

# Plot train
for row in ax:
    for col in row:
        col.hist(params[k[c]]['train_means'], bins = 30, color = colors[c], alpha = 0.5, label = 'Train')
        col.set_title(params[k[c]]['label'])
        c += 1

# Plot test
for row in ax:
    for col in row:
        col.hist(params[k[c-4]]['test_means'], bins = 30, color = colors[c], alpha = 0.5, label = 'Test')
        col.set_title(params[k[c-4]]['label'])
        col.legend(loc = 'best')
        c += 1


# Plot test
fig.suptitle('Prediction Distributions', fontsize = 24)

plt.show()
