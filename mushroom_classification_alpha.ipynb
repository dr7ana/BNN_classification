# %%
# standard
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pl

# os
import os

# sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# tf
import tensorflow as tf
import tensorflow_probability as tfp
tfd = tfp.distributions
tfb = tfp.bijectors

# keras
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Layer, Input, Activation, Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras import optimizers
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K
from keras.regularizers import l1,l2
from keras.utils.vis_utils import plot_model

# %%
# Import data
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Make pd df
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Mushroom Classification Project/mushrooms.csv')

# %% [markdown]
# #### Data Topology:
#
# -	cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
# -	cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
# -	cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y
# -	bruises: bruises=t,no=f
# -	odor: almond=a,anise=l,creosote=c,fishy=y,foul=f,musty=m,none=n,pungent=p,spicy=s
# -	gill-attachment: attached=a,descending=d,free=f,notched=n
# -	gill-spacing: close=c,crowded=w,distant=d
# -	gill-size: broad=b,narrow=n
# -	gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e,white=w,yellow=y
# -	stalk-shape: enlarging=e,tapering=t
# -	stalk-root: bulbous=b,club=c,cup=u,equal=e,rhizomorphs=z,rooted=r,missing=?
# -	stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
# -	stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
# -	stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
# -	stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
# -	veil-type: partial=p,universal=u
# -	veil-color: brown=n,orange=o,white=w,yellow=y
# -	ring-number: none=n,one=o,two=t
# -	ring-type: cobwebby=c,evanescent=e,flaring=f,large=l,none=n,pendant=p,sheathing=s,zone=z
# -	spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r,orange=o,purple=u,white=w,yellow=y
# -	population: abundant=a,clustered=c,numerous=n,scattered=s,several=v,solitary=y
# -	habitat: grasses=g,leaves=l,meadows=m,paths=p,urban=u,waste=w,woods=d

# %%
# Categorical encoding

for feat in df.columns:
    # extract unique column values
    vals = np.unique(df[feat].values)
    # fit labelencoder
    le = LabelEncoder()
    le.fit(df[feat])
    # transform dataset
    df[feat] = le.transform(df[feat])

# %%
# Extract list of training features
tfeatures = np.array(df.columns)[1:]
features = np.array(df.columns)

# %%
# Split into train/target
_target = df.pop('class')
_train = df

# %%
# Train size
train_size = 6499

# Make train/test data
x_train = {}
x_test = {}
y_train = []
y_test = []

# %%
# Populate x_train, x_test
for f in tfeatures:
    x_train[f] = _train[f][:train_size+1]
    x_test[f] = _train[f][train_size:]

# %%
# Populate y_train, y_test
y_train = _target[:train_size+1]
y_test = _target[train_size:]

# %%
# Custom activation function
def swish(x):
    return (K.sigmoid(x) * x)

get_custom_objects().update({'swish': Activation(swish)})

# %%
# Custom loss function
def neg_log_likelihood(targets, estimate):
    return -estimate.log_prob(targets)

# %%
# BNN Model

# Prior weights will remain fixed and untrained
#   mean = 0
#   std-dev = 1
def prior_weights_model(kernel_size, bias_size, dtype = None):
    units = kernel_size + bias_size
    pw = Sequential()
    pw.add(
        tfp.layers.DistributionLambda(
            lambda x: tfd.MultivariateNormalDiag(loc = tf.zeros(units), 
                                                 scale_diag = tf.ones(units) )
        ) 
    )
    return pw

# Posterior weights will be trained and unfixed
#   learnable params are mean, variance, and covariance
def posterior_inference_model(kernel_size, bias_size, dtype = None):
    units = kernel_size + bias_size
    pi = Sequential()
    pi.add(
        tfp.layers.VariableLayer(
            tfp.layers.MultivariateNormalTriL.params_size(units), dtype = dtype
        )
    )
    pi.add(
        tfp.layers.MultivariateNormalTriL(units)
    )
    return pi

# This function will produce an input tensor for each feature extracted from the df
#   keras.layers.Input produces a keras tensor with a specific feature name
#   this will allow us to later quantify inference for each feature
def populate_input_tensors(_features = tfeatures):
    inputs = {}
    for f in _features:
        inputs[f] = Input(name = f, shape = (1,), dtype = tf.float32)
    return inputs

# training_size = len(x_train)
def _BNN(n_units = 2, lr = 0.001, training_size = 650, hidden_units = 8, activ = 'sigmoid'):
    input_layers = populate_input_tensors()
    feature_layers = keras.layers.concatenate( list(input_layers.values()) )
    feature_layers = keras.layers.BatchNormalization()(feature_layers)

    for u in np.full(shape = n_units, fill_value = hidden_units):
        feature_layers = tfp.layers.DenseVariational(
            units = u,
            make_posterior_fn = posterior_inference_model,
            make_prior_fn = prior_weights_model,
            kl_weight = 1 / training_size,
            activation = activ)(feature_layers)

    # Probabilistic output model
    #   Dense layer: used to produce distribution parameters
    #   IndependentBernoulli: used for binary classification
    dist_params = Dense(units = 8)(feature_layers)
    output_layers = tfp.layers.IndependentBernoulli(8)(dist_params)

    model = keras.Model(inputs = input_layers, outputs = output_layers)
    model.compile(optimizer = keras.optimizers.RMSprop(learning_rate = lr), 
                  metrics = [keras.metrics.RootMeanSquaredError()], 
                  loss = neg_log_likelihood)
    return model

# %%
params = {
    'bnn_a1':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':6, 'lr':0.001, 'activ':'sigmoid', 'label':'BNN A - lr=1e-3', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_a2':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':6, 'lr':0.0005, 'activ':'sigmoid', 'label':'BNN A - lr=5e-4', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_a3':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':6, 'lr':0.005, 'activ':'sigmoid', 'label':'BNN A - lr=5e-3', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_b1':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':8, 'lr':0.001, 'activ':'sigmoid', 'label':'BNN B - lr=1e-3', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_b2':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':8, 'lr':0.0005, 'activ':'sigmoid', 'label':'BNN B - lr=5e-4', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_b3':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':8, 'lr':0.005, 'activ':'sigmoid', 'label':'BNN B - lr=5e-3', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_c1':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':10, 'lr':0.001, 'activ':'sigmoid', 'label':'BNN C - lr=1e-3', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_c2':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':10, 'lr':0.0005, 'activ':'sigmoid', 'label':'BNN C - lr=5e-4', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_c3':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':10, 'lr':0.005, 'activ':'sigmoid', 'label':'BNN C - lr=5e-3', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''}
}

# %%
# Parameters
n_epoches = 200
batch_size = 128

# %%
# Train cross-validated NN model
for k in params.keys():
    tf.random.set_seed(0)
    model = params[k]['function'](n_units = params[k]['n_units'], lr = params[k]['lr'], training_size = len(y_train), hidden_units = params[k]['hidden_units'])
    params[k]['history'] = model.fit(x = x_train, y = y_train, validation_data = (x_test, y_test), epochs = n_epoches, batch_size = batch_size, shuffle = True)
    params[k]['model'] = model
# Out:
# Epoch 1/200
# 51/51 [==============================] - 3s 19ms/step - loss: 5.5797 - root_mean_squared_error: 0.7056 - val_loss: 5.9052 - val_root_mean_squared_error: 0.7188
# Epoch 2/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5383 - root_mean_squared_error: 0.7045 - val_loss: 5.9449 - val_root_mean_squared_error: 0.7200
# Epoch 3/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5177 - root_mean_squared_error: 0.7024 - val_loss: 6.0303 - val_root_mean_squared_error: 0.7231
# Epoch 4/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5142 - root_mean_squared_error: 0.7006 - val_loss: 5.9591 - val_root_mean_squared_error: 0.7195
# Epoch 5/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5052 - root_mean_squared_error: 0.7012 - val_loss: 6.0484 - val_root_mean_squared_error: 0.7208
# Epoch 6/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4999 - root_mean_squared_error: 0.6975 - val_loss: 5.9810 - val_root_mean_squared_error: 0.7193
# Epoch 7/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4981 - root_mean_squared_error: 0.7013 - val_loss: 6.0371 - val_root_mean_squared_error: 0.7235
# Epoch 8/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.5052 - root_mean_squared_error: 0.7007 - val_loss: 5.9685 - val_root_mean_squared_error: 0.7221
# Epoch 9/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.5021 - root_mean_squared_error: 0.7008 - val_loss: 6.1092 - val_root_mean_squared_error: 0.7295
# Epoch 10/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5039 - root_mean_squared_error: 0.7037 - val_loss: 6.0223 - val_root_mean_squared_error: 0.7230
# Epoch 11/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4991 - root_mean_squared_error: 0.7025 - val_loss: 6.0351 - val_root_mean_squared_error: 0.7216
# Epoch 12/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4893 - root_mean_squared_error: 0.6986 - val_loss: 6.0208 - val_root_mean_squared_error: 0.7248
# Epoch 13/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4923 - root_mean_squared_error: 0.7033 - val_loss: 6.0265 - val_root_mean_squared_error: 0.7224
# Epoch 14/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4947 - root_mean_squared_error: 0.7021 - val_loss: 6.0783 - val_root_mean_squared_error: 0.7274
# Epoch 15/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4795 - root_mean_squared_error: 0.6976 - val_loss: 6.0603 - val_root_mean_squared_error: 0.7247
# Epoch 16/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4917 - root_mean_squared_error: 0.7001 - val_loss: 6.0103 - val_root_mean_squared_error: 0.7235
# Epoch 17/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4911 - root_mean_squared_error: 0.7000 - val_loss: 6.0319 - val_root_mean_squared_error: 0.7258
# Epoch 18/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4898 - root_mean_squared_error: 0.6991 - val_loss: 5.9677 - val_root_mean_squared_error: 0.7206
# Epoch 19/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4670 - root_mean_squared_error: 0.7019 - val_loss: 6.1113 - val_root_mean_squared_error: 0.7233
# Epoch 20/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4817 - root_mean_squared_error: 0.6973 - val_loss: 6.0336 - val_root_mean_squared_error: 0.7243
# Epoch 21/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4772 - root_mean_squared_error: 0.7002 - val_loss: 6.0740 - val_root_mean_squared_error: 0.7210
# Epoch 22/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4565 - root_mean_squared_error: 0.6995 - val_loss: 6.0409 - val_root_mean_squared_error: 0.7269
# Epoch 23/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4678 - root_mean_squared_error: 0.6992 - val_loss: 6.0517 - val_root_mean_squared_error: 0.7312
# Epoch 24/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4584 - root_mean_squared_error: 0.7022 - val_loss: 6.0935 - val_root_mean_squared_error: 0.7275
# Epoch 25/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4419 - root_mean_squared_error: 0.6991 - val_loss: 6.0219 - val_root_mean_squared_error: 0.7206
# Epoch 26/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4202 - root_mean_squared_error: 0.6983 - val_loss: 5.9910 - val_root_mean_squared_error: 0.7233
# Epoch 27/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4310 - root_mean_squared_error: 0.6967 - val_loss: 6.0872 - val_root_mean_squared_error: 0.7268
# Epoch 28/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.3684 - root_mean_squared_error: 0.6904 - val_loss: 6.0835 - val_root_mean_squared_error: 0.7224
# Epoch 29/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.3336 - root_mean_squared_error: 0.6900 - val_loss: 5.8971 - val_root_mean_squared_error: 0.7203
# Epoch 30/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.2534 - root_mean_squared_error: 0.6831 - val_loss: 5.9605 - val_root_mean_squared_error: 0.7187
# Epoch 31/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.1996 - root_mean_squared_error: 0.6879 - val_loss: 5.9987 - val_root_mean_squared_error: 0.7194
# Epoch 32/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.1099 - root_mean_squared_error: 0.6812 - val_loss: 5.9068 - val_root_mean_squared_error: 0.7201
# Epoch 33/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.0430 - root_mean_squared_error: 0.6733 - val_loss: 5.7732 - val_root_mean_squared_error: 0.7099
# Epoch 34/200
# 51/51 [==============================] - 0s 6ms/step - loss: 4.9106 - root_mean_squared_error: 0.6666 - val_loss: 5.7522 - val_root_mean_squared_error: 0.7069
# Epoch 35/200
# 51/51 [==============================] - 0s 6ms/step - loss: 4.7408 - root_mean_squared_error: 0.6565 - val_loss: 5.4405 - val_root_mean_squared_error: 0.6996
# Epoch 36/200
# 51/51 [==============================] - 0s 6ms/step - loss: 4.5717 - root_mean_squared_error: 0.6449 - val_loss: 5.2624 - val_root_mean_squared_error: 0.6892
# Epoch 37/200
# 51/51 [==============================] - 0s 6ms/step - loss: 4.4780 - root_mean_squared_error: 0.6397 - val_loss: 5.3278 - val_root_mean_squared_error: 0.6919
# Epoch 38/200
# 51/51 [==============================] - 0s 6ms/step - loss: 4.2521 - root_mean_squared_error: 0.6220 - val_loss: 4.6836 - val_root_mean_squared_error: 0.6590
# Epoch 39/200
# 51/51 [==============================] - 0s 7ms/step - loss: 4.1353 - root_mean_squared_error: 0.6107 - val_loss: 4.5983 - val_root_mean_squared_error: 0.6548
# Epoch 40/200
# 51/51 [==============================] - 0s 7ms/step - loss: 3.9550 - root_mean_squared_error: 0.6042 - val_loss: 4.6707 - val_root_mean_squared_error: 0.6563
# Epoch 41/200
# 51/51 [==============================] - 0s 6ms/step - loss: 3.7362 - root_mean_squared_error: 0.5833 - val_loss: 4.3882 - val_root_mean_squared_error: 0.6424
# Epoch 42/200
# 51/51 [==============================] - 0s 6ms/step - loss: 3.6081 - root_mean_squared_error: 0.5778 - val_loss: 4.4349 - val_root_mean_squared_error: 0.6446
# Epoch 43/200
# 51/51 [==============================] - 0s 6ms/step - loss: 3.4374 - root_mean_squared_error: 0.5557 - val_loss: 3.9916 - val_root_mean_squared_error: 0.6197
# Epoch 44/200
# 51/51 [==============================] - 0s 6ms/step - loss: 3.2661 - root_mean_squared_error: 0.5505 - val_loss: 3.9309 - val_root_mean_squared_error: 0.6102
# Epoch 45/200
# 51/51 [==============================] - 0s 6ms/step - loss: 3.1727 - root_mean_squared_error: 0.5399 - val_loss: 4.1293 - val_root_mean_squared_error: 0.6257
# Epoch 46/200
# 51/51 [==============================] - 0s 6ms/step - loss: 3.0424 - root_mean_squared_error: 0.5303 - val_loss: 3.5764 - val_root_mean_squared_error: 0.5886
# Epoch 47/200
# 51/51 [==============================] - 0s 6ms/step - loss: 2.9684 - root_mean_squared_error: 0.5197 - val_loss: 3.3501 - val_root_mean_squared_error: 0.5700
# Epoch 48/200
# 51/51 [==============================] - 0s 6ms/step - loss: 2.7418 - root_mean_squared_error: 0.5052 - val_loss: 3.5962 - val_root_mean_squared_error: 0.5912
# Epoch 49/200
# 51/51 [==============================] - 0s 6ms/step - loss: 2.6836 - root_mean_squared_error: 0.4989 - val_loss: 3.2804 - val_root_mean_squared_error: 0.5649
# Epoch 50/200
# 51/51 [==============================] - 0s 6ms/step - loss: 2.6023 - root_mean_squared_error: 0.4906 - val_loss: 3.4653 - val_root_mean_squared_error: 0.5772
# Epoch 51/200
# 51/51 [==============================] - 0s 6ms/step - loss: 2.4895 - root_mean_squared_error: 0.4797 - val_loss: 3.3539 - val_root_mean_squared_error: 0.5608
# Epoch 52/200
# 51/51 [==============================] - 0s 7ms/step - loss: 2.3878 - root_mean_squared_error: 0.4701 - val_loss: 3.6305 - val_root_mean_squared_error: 0.5857
# Epoch 53/200
# 51/51 [==============================] - 0s 6ms/step - loss: 2.3573 - root_mean_squared_error: 0.4654 - val_loss: 3.0433 - val_root_mean_squared_error: 0.5472
# Epoch 54/200
# 51/51 [==============================] - 0s 6ms/step - loss: 2.2803 - root_mean_squared_error: 0.4539 - val_loss: 2.9548 - val_root_mean_squared_error: 0.5327
# Epoch 55/200
# 51/51 [==============================] - 0s 6ms/step - loss: 2.1196 - root_mean_squared_error: 0.4387 - val_loss: 3.0016 - val_root_mean_squared_error: 0.5310
# Epoch 56/200
# 51/51 [==============================] - 0s 6ms/step - loss: 2.1423 - root_mean_squared_error: 0.4415 - val_loss: 3.1679 - val_root_mean_squared_error: 0.5498
# Epoch 57/200
# 51/51 [==============================] - 0s 6ms/step - loss: 2.0679 - root_mean_squared_error: 0.4277 - val_loss: 2.5259 - val_root_mean_squared_error: 0.4975
# Epoch 58/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.9952 - root_mean_squared_error: 0.4244 - val_loss: 2.6584 - val_root_mean_squared_error: 0.5044
# Epoch 59/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.9874 - root_mean_squared_error: 0.4195 - val_loss: 2.5938 - val_root_mean_squared_error: 0.4967
# Epoch 60/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.9155 - root_mean_squared_error: 0.4128 - val_loss: 2.3677 - val_root_mean_squared_error: 0.4789
# Epoch 61/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.8899 - root_mean_squared_error: 0.4083 - val_loss: 2.9904 - val_root_mean_squared_error: 0.5081
# Epoch 62/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.8261 - root_mean_squared_error: 0.3990 - val_loss: 2.2928 - val_root_mean_squared_error: 0.4747
# Epoch 63/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.7960 - root_mean_squared_error: 0.3977 - val_loss: 2.7188 - val_root_mean_squared_error: 0.4906
# Epoch 64/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.7547 - root_mean_squared_error: 0.3887 - val_loss: 2.5816 - val_root_mean_squared_error: 0.4703
# Epoch 65/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.6963 - root_mean_squared_error: 0.3852 - val_loss: 2.2338 - val_root_mean_squared_error: 0.4598
# Epoch 66/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.7058 - root_mean_squared_error: 0.3795 - val_loss: 2.5117 - val_root_mean_squared_error: 0.4720
# Epoch 67/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.6345 - root_mean_squared_error: 0.3735 - val_loss: 2.1057 - val_root_mean_squared_error: 0.4377
# Epoch 68/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.6375 - root_mean_squared_error: 0.3716 - val_loss: 2.4322 - val_root_mean_squared_error: 0.4654
# Epoch 69/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.5991 - root_mean_squared_error: 0.3693 - val_loss: 1.8727 - val_root_mean_squared_error: 0.4136
# Epoch 70/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.5633 - root_mean_squared_error: 0.3634 - val_loss: 1.9286 - val_root_mean_squared_error: 0.4230
# Epoch 71/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.5557 - root_mean_squared_error: 0.3607 - val_loss: 2.0247 - val_root_mean_squared_error: 0.4190
# Epoch 72/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.5324 - root_mean_squared_error: 0.3548 - val_loss: 2.3067 - val_root_mean_squared_error: 0.4470
# Epoch 73/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.5476 - root_mean_squared_error: 0.3527 - val_loss: 2.3925 - val_root_mean_squared_error: 0.4443
# Epoch 74/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.4691 - root_mean_squared_error: 0.3482 - val_loss: 2.2762 - val_root_mean_squared_error: 0.4283
# Epoch 75/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.4214 - root_mean_squared_error: 0.3426 - val_loss: 2.2259 - val_root_mean_squared_error: 0.4356
# Epoch 76/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.4378 - root_mean_squared_error: 0.3443 - val_loss: 2.3222 - val_root_mean_squared_error: 0.4395
# Epoch 77/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.4345 - root_mean_squared_error: 0.3379 - val_loss: 2.3915 - val_root_mean_squared_error: 0.4303
# Epoch 78/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.3927 - root_mean_squared_error: 0.3337 - val_loss: 2.0281 - val_root_mean_squared_error: 0.4045
# Epoch 79/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.3614 - root_mean_squared_error: 0.3318 - val_loss: 2.5201 - val_root_mean_squared_error: 0.4452
# Epoch 80/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.3661 - root_mean_squared_error: 0.3273 - val_loss: 2.1487 - val_root_mean_squared_error: 0.4127
# Epoch 81/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.3275 - root_mean_squared_error: 0.3217 - val_loss: 2.5288 - val_root_mean_squared_error: 0.4250
# Epoch 82/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.3644 - root_mean_squared_error: 0.3197 - val_loss: 1.8505 - val_root_mean_squared_error: 0.3866
# Epoch 83/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.3146 - root_mean_squared_error: 0.3206 - val_loss: 2.2009 - val_root_mean_squared_error: 0.4166
# Epoch 84/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.3560 - root_mean_squared_error: 0.3166 - val_loss: 2.1486 - val_root_mean_squared_error: 0.3943
# Epoch 85/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.3500 - root_mean_squared_error: 0.3158 - val_loss: 2.3317 - val_root_mean_squared_error: 0.4107
# Epoch 86/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.2754 - root_mean_squared_error: 0.3107 - val_loss: 2.3299 - val_root_mean_squared_error: 0.4114
# Epoch 87/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.3052 - root_mean_squared_error: 0.3070 - val_loss: 2.0316 - val_root_mean_squared_error: 0.3849
# Epoch 88/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.2862 - root_mean_squared_error: 0.3098 - val_loss: 2.5848 - val_root_mean_squared_error: 0.4156
# Epoch 89/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.2392 - root_mean_squared_error: 0.3052 - val_loss: 1.8601 - val_root_mean_squared_error: 0.3746
# Epoch 90/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.2234 - root_mean_squared_error: 0.3001 - val_loss: 2.4260 - val_root_mean_squared_error: 0.3985
# Epoch 91/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.2732 - root_mean_squared_error: 0.3013 - val_loss: 1.9649 - val_root_mean_squared_error: 0.3765
# Epoch 92/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.2866 - root_mean_squared_error: 0.2981 - val_loss: 1.9778 - val_root_mean_squared_error: 0.3649
# Epoch 93/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.2395 - root_mean_squared_error: 0.2964 - val_loss: 2.0688 - val_root_mean_squared_error: 0.3891
# Epoch 94/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1876 - root_mean_squared_error: 0.2928 - val_loss: 1.8114 - val_root_mean_squared_error: 0.3701
# Epoch 95/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2021 - root_mean_squared_error: 0.2913 - val_loss: 2.0716 - val_root_mean_squared_error: 0.3781
# Epoch 96/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1913 - root_mean_squared_error: 0.2914 - val_loss: 1.7345 - val_root_mean_squared_error: 0.3551
# Epoch 97/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1708 - root_mean_squared_error: 0.2858 - val_loss: 2.6711 - val_root_mean_squared_error: 0.4157
# Epoch 98/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1935 - root_mean_squared_error: 0.2886 - val_loss: 1.8943 - val_root_mean_squared_error: 0.3564
# Epoch 99/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1799 - root_mean_squared_error: 0.2898 - val_loss: 2.7290 - val_root_mean_squared_error: 0.4065
# Epoch 100/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1697 - root_mean_squared_error: 0.2821 - val_loss: 2.6891 - val_root_mean_squared_error: 0.4049
# Epoch 101/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1824 - root_mean_squared_error: 0.2848 - val_loss: 2.3007 - val_root_mean_squared_error: 0.3825
# Epoch 102/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2068 - root_mean_squared_error: 0.2862 - val_loss: 1.8726 - val_root_mean_squared_error: 0.3594
# Epoch 103/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1615 - root_mean_squared_error: 0.2790 - val_loss: 1.7625 - val_root_mean_squared_error: 0.3582
# Epoch 104/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1970 - root_mean_squared_error: 0.2821 - val_loss: 2.7229 - val_root_mean_squared_error: 0.4187
# Epoch 105/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.2132 - root_mean_squared_error: 0.2829 - val_loss: 1.7949 - val_root_mean_squared_error: 0.3531
# Epoch 106/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1301 - root_mean_squared_error: 0.2748 - val_loss: 2.0817 - val_root_mean_squared_error: 0.3649
# Epoch 107/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1274 - root_mean_squared_error: 0.2739 - val_loss: 1.7375 - val_root_mean_squared_error: 0.3428
# Epoch 108/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1695 - root_mean_squared_error: 0.2758 - val_loss: 1.7754 - val_root_mean_squared_error: 0.3230
# Epoch 109/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1189 - root_mean_squared_error: 0.2737 - val_loss: 2.2353 - val_root_mean_squared_error: 0.3779
# Epoch 110/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1477 - root_mean_squared_error: 0.2728 - val_loss: 2.0500 - val_root_mean_squared_error: 0.3725
# Epoch 111/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0753 - root_mean_squared_error: 0.2665 - val_loss: 1.9004 - val_root_mean_squared_error: 0.3687
# Epoch 112/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1317 - root_mean_squared_error: 0.2738 - val_loss: 2.1446 - val_root_mean_squared_error: 0.3796
# Epoch 113/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1020 - root_mean_squared_error: 0.2679 - val_loss: 1.9638 - val_root_mean_squared_error: 0.3775
# Epoch 114/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1363 - root_mean_squared_error: 0.2701 - val_loss: 1.9434 - val_root_mean_squared_error: 0.3671
# Epoch 115/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1590 - root_mean_squared_error: 0.2712 - val_loss: 2.0925 - val_root_mean_squared_error: 0.3852
# Epoch 116/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1269 - root_mean_squared_error: 0.2673 - val_loss: 1.9268 - val_root_mean_squared_error: 0.3667
# Epoch 117/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1620 - root_mean_squared_error: 0.2719 - val_loss: 1.7728 - val_root_mean_squared_error: 0.3437
# Epoch 118/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0927 - root_mean_squared_error: 0.2654 - val_loss: 1.7943 - val_root_mean_squared_error: 0.3349
# Epoch 119/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0584 - root_mean_squared_error: 0.2609 - val_loss: 1.7241 - val_root_mean_squared_error: 0.3405
# Epoch 120/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1168 - root_mean_squared_error: 0.2660 - val_loss: 2.4495 - val_root_mean_squared_error: 0.4058
# Epoch 121/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1131 - root_mean_squared_error: 0.2628 - val_loss: 1.7861 - val_root_mean_squared_error: 0.3388
# Epoch 122/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0708 - root_mean_squared_error: 0.2572 - val_loss: 1.9098 - val_root_mean_squared_error: 0.3530
# Epoch 123/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0842 - root_mean_squared_error: 0.2613 - val_loss: 2.3736 - val_root_mean_squared_error: 0.3690
# Epoch 124/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0783 - root_mean_squared_error: 0.2601 - val_loss: 1.7492 - val_root_mean_squared_error: 0.3425
# Epoch 125/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.1559 - root_mean_squared_error: 0.2650 - val_loss: 1.8849 - val_root_mean_squared_error: 0.3421
# Epoch 126/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0664 - root_mean_squared_error: 0.2595 - val_loss: 2.7067 - val_root_mean_squared_error: 0.4024
# Epoch 127/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0902 - root_mean_squared_error: 0.2598 - val_loss: 2.6715 - val_root_mean_squared_error: 0.4085
# Epoch 128/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0615 - root_mean_squared_error: 0.2559 - val_loss: 1.8880 - val_root_mean_squared_error: 0.3389
# Epoch 129/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0417 - root_mean_squared_error: 0.2543 - val_loss: 2.0224 - val_root_mean_squared_error: 0.3547
# Epoch 130/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0675 - root_mean_squared_error: 0.2597 - val_loss: 2.6977 - val_root_mean_squared_error: 0.4203
# Epoch 131/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0210 - root_mean_squared_error: 0.2515 - val_loss: 2.7282 - val_root_mean_squared_error: 0.4132
# Epoch 132/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0080 - root_mean_squared_error: 0.2506 - val_loss: 2.1062 - val_root_mean_squared_error: 0.3652
# Epoch 133/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0450 - root_mean_squared_error: 0.2555 - val_loss: 2.2483 - val_root_mean_squared_error: 0.3757
# Epoch 134/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0601 - root_mean_squared_error: 0.2587 - val_loss: 2.5220 - val_root_mean_squared_error: 0.3962
# Epoch 135/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0808 - root_mean_squared_error: 0.2531 - val_loss: 2.4115 - val_root_mean_squared_error: 0.3904
# Epoch 136/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0505 - root_mean_squared_error: 0.2540 - val_loss: 2.3558 - val_root_mean_squared_error: 0.3746
# Epoch 137/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0210 - root_mean_squared_error: 0.2485 - val_loss: 2.3133 - val_root_mean_squared_error: 0.3849
# Epoch 138/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0444 - root_mean_squared_error: 0.2488 - val_loss: 2.1718 - val_root_mean_squared_error: 0.3676
# Epoch 139/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0317 - root_mean_squared_error: 0.2477 - val_loss: 2.6372 - val_root_mean_squared_error: 0.3981
# Epoch 140/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9944 - root_mean_squared_error: 0.2459 - val_loss: 2.9393 - val_root_mean_squared_error: 0.4246
# Epoch 141/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1166 - root_mean_squared_error: 0.2569 - val_loss: 2.7531 - val_root_mean_squared_error: 0.4055
# Epoch 142/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0188 - root_mean_squared_error: 0.2520 - val_loss: 2.0186 - val_root_mean_squared_error: 0.3643
# Epoch 143/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9936 - root_mean_squared_error: 0.2485 - val_loss: 2.5954 - val_root_mean_squared_error: 0.3861
# Epoch 144/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0532 - root_mean_squared_error: 0.2472 - val_loss: 2.2705 - val_root_mean_squared_error: 0.3688
# Epoch 145/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0283 - root_mean_squared_error: 0.2502 - val_loss: 2.0791 - val_root_mean_squared_error: 0.3541
# Epoch 146/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9829 - root_mean_squared_error: 0.2448 - val_loss: 1.9389 - val_root_mean_squared_error: 0.3416
# Epoch 147/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0117 - root_mean_squared_error: 0.2416 - val_loss: 3.1097 - val_root_mean_squared_error: 0.4217
# Epoch 148/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9679 - root_mean_squared_error: 0.2438 - val_loss: 2.3923 - val_root_mean_squared_error: 0.3601
# Epoch 149/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0290 - root_mean_squared_error: 0.2478 - val_loss: 2.1334 - val_root_mean_squared_error: 0.3528
# Epoch 150/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0006 - root_mean_squared_error: 0.2447 - val_loss: 2.4098 - val_root_mean_squared_error: 0.3735
# Epoch 151/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0227 - root_mean_squared_error: 0.2485 - val_loss: 2.0878 - val_root_mean_squared_error: 0.3681
# Epoch 152/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9664 - root_mean_squared_error: 0.2439 - val_loss: 2.6212 - val_root_mean_squared_error: 0.3839
# Epoch 153/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0132 - root_mean_squared_error: 0.2487 - val_loss: 2.8613 - val_root_mean_squared_error: 0.3912
# Epoch 154/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0307 - root_mean_squared_error: 0.2487 - val_loss: 2.1607 - val_root_mean_squared_error: 0.3746
# Epoch 155/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9913 - root_mean_squared_error: 0.2411 - val_loss: 2.7947 - val_root_mean_squared_error: 0.4133
# Epoch 156/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0515 - root_mean_squared_error: 0.2519 - val_loss: 2.6045 - val_root_mean_squared_error: 0.3958
# Epoch 157/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9840 - root_mean_squared_error: 0.2443 - val_loss: 2.9099 - val_root_mean_squared_error: 0.4179
# Epoch 158/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9932 - root_mean_squared_error: 0.2451 - val_loss: 2.5855 - val_root_mean_squared_error: 0.3781
# Epoch 159/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0503 - root_mean_squared_error: 0.2497 - val_loss: 2.5551 - val_root_mean_squared_error: 0.3973
# Epoch 160/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0472 - root_mean_squared_error: 0.2469 - val_loss: 3.0558 - val_root_mean_squared_error: 0.4261
# Epoch 161/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0235 - root_mean_squared_error: 0.2464 - val_loss: 2.4303 - val_root_mean_squared_error: 0.3896
# Epoch 162/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0588 - root_mean_squared_error: 0.2491 - val_loss: 2.5469 - val_root_mean_squared_error: 0.3863
# Epoch 163/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9873 - root_mean_squared_error: 0.2425 - val_loss: 2.6909 - val_root_mean_squared_error: 0.4015
# Epoch 164/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0053 - root_mean_squared_error: 0.2406 - val_loss: 2.8541 - val_root_mean_squared_error: 0.3915
# Epoch 165/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9870 - root_mean_squared_error: 0.2427 - val_loss: 3.1198 - val_root_mean_squared_error: 0.4131
# Epoch 166/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9784 - root_mean_squared_error: 0.2389 - val_loss: 2.3997 - val_root_mean_squared_error: 0.3868
# Epoch 167/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9492 - root_mean_squared_error: 0.2384 - val_loss: 2.5202 - val_root_mean_squared_error: 0.3908
# Epoch 168/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9743 - root_mean_squared_error: 0.2414 - val_loss: 2.6964 - val_root_mean_squared_error: 0.3957
# Epoch 169/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9838 - root_mean_squared_error: 0.2387 - val_loss: 2.7314 - val_root_mean_squared_error: 0.4026
# Epoch 170/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9508 - root_mean_squared_error: 0.2385 - val_loss: 2.6704 - val_root_mean_squared_error: 0.3973
# Epoch 171/200
# 51/51 [==============================] - 0s 6ms/step - loss: 1.0248 - root_mean_squared_error: 0.2419 - val_loss: 2.4475 - val_root_mean_squared_error: 0.3723
# Epoch 172/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9825 - root_mean_squared_error: 0.2410 - val_loss: 2.6625 - val_root_mean_squared_error: 0.3975
# Epoch 173/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9866 - root_mean_squared_error: 0.2418 - val_loss: 2.3125 - val_root_mean_squared_error: 0.3723
# Epoch 174/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9492 - root_mean_squared_error: 0.2385 - val_loss: 2.5054 - val_root_mean_squared_error: 0.3670
# Epoch 175/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9696 - root_mean_squared_error: 0.2378 - val_loss: 2.8366 - val_root_mean_squared_error: 0.3948
# Epoch 176/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9593 - root_mean_squared_error: 0.2407 - val_loss: 2.5589 - val_root_mean_squared_error: 0.3743
# Epoch 177/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9664 - root_mean_squared_error: 0.2408 - val_loss: 3.4801 - val_root_mean_squared_error: 0.4431
# Epoch 178/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9664 - root_mean_squared_error: 0.2368 - val_loss: 3.1087 - val_root_mean_squared_error: 0.4145
# Epoch 179/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9674 - root_mean_squared_error: 0.2405 - val_loss: 2.7116 - val_root_mean_squared_error: 0.4030
# Epoch 180/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9952 - root_mean_squared_error: 0.2412 - val_loss: 2.9980 - val_root_mean_squared_error: 0.4088
# Epoch 181/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9385 - root_mean_squared_error: 0.2354 - val_loss: 2.5891 - val_root_mean_squared_error: 0.3896
# Epoch 182/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9646 - root_mean_squared_error: 0.2363 - val_loss: 3.0702 - val_root_mean_squared_error: 0.4009
# Epoch 183/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9464 - root_mean_squared_error: 0.2358 - val_loss: 2.6404 - val_root_mean_squared_error: 0.3785
# Epoch 184/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9590 - root_mean_squared_error: 0.2359 - val_loss: 2.6828 - val_root_mean_squared_error: 0.3817
# Epoch 185/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9598 - root_mean_squared_error: 0.2405 - val_loss: 2.3494 - val_root_mean_squared_error: 0.3731
# Epoch 186/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9525 - root_mean_squared_error: 0.2376 - val_loss: 2.4622 - val_root_mean_squared_error: 0.3771
# Epoch 187/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9714 - root_mean_squared_error: 0.2389 - val_loss: 3.5408 - val_root_mean_squared_error: 0.4553
# Epoch 188/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9828 - root_mean_squared_error: 0.2397 - val_loss: 2.1957 - val_root_mean_squared_error: 0.3673
# Epoch 189/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9523 - root_mean_squared_error: 0.2360 - val_loss: 2.9117 - val_root_mean_squared_error: 0.4130
# Epoch 190/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9904 - root_mean_squared_error: 0.2408 - val_loss: 3.0738 - val_root_mean_squared_error: 0.4043
# Epoch 191/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9645 - root_mean_squared_error: 0.2340 - val_loss: 4.0291 - val_root_mean_squared_error: 0.4592
# Epoch 192/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9909 - root_mean_squared_error: 0.2414 - val_loss: 2.4428 - val_root_mean_squared_error: 0.3667
# Epoch 193/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9413 - root_mean_squared_error: 0.2350 - val_loss: 2.5538 - val_root_mean_squared_error: 0.3759
# Epoch 194/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9441 - root_mean_squared_error: 0.2347 - val_loss: 2.2925 - val_root_mean_squared_error: 0.3635
# Epoch 195/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9446 - root_mean_squared_error: 0.2332 - val_loss: 2.6781 - val_root_mean_squared_error: 0.3942
# Epoch 196/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9348 - root_mean_squared_error: 0.2349 - val_loss: 2.8864 - val_root_mean_squared_error: 0.3947
# Epoch 197/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9436 - root_mean_squared_error: 0.2292 - val_loss: 2.3609 - val_root_mean_squared_error: 0.3636
# Epoch 198/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9879 - root_mean_squared_error: 0.2354 - val_loss: 2.4914 - val_root_mean_squared_error: 0.3698
# Epoch 199/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9289 - root_mean_squared_error: 0.2312 - val_loss: 2.2764 - val_root_mean_squared_error: 0.3679
# Epoch 200/200
# 51/51 [==============================] - 0s 6ms/step - loss: 0.9242 - root_mean_squared_error: 0.2320 - val_loss: 3.2915 - val_root_mean_squared_error: 0.4369
# Epoch 1/200
# 51/51 [==============================] - 3s 20ms/step - loss: 5.5980 - root_mean_squared_error: 0.7062 - val_loss: 5.8470 - val_root_mean_squared_error: 0.7158
# Epoch 2/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.5681 - root_mean_squared_error: 0.7054 - val_loss: 5.8563 - val_root_mean_squared_error: 0.7167
# Epoch 3/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5420 - root_mean_squared_error: 0.7041 - val_loss: 5.9263 - val_root_mean_squared_error: 0.7184
# Epoch 4/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5324 - root_mean_squared_error: 0.7015 - val_loss: 5.8843 - val_root_mean_squared_error: 0.7174
# Epoch 5/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.5185 - root_mean_squared_error: 0.7027 - val_loss: 5.9848 - val_root_mean_squared_error: 0.7173
# Epoch 6/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5111 - root_mean_squared_error: 0.6987 - val_loss: 5.9169 - val_root_mean_squared_error: 0.7169
# Epoch 7/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.5122 - root_mean_squared_error: 0.7026 - val_loss: 6.0046 - val_root_mean_squared_error: 0.7223
# Epoch 8/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.5087 - root_mean_squared_error: 0.7010 - val_loss: 5.9512 - val_root_mean_squared_error: 0.7213
# Epoch 9/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5090 - root_mean_squared_error: 0.7011 - val_loss: 6.0790 - val_root_mean_squared_error: 0.7286
# Epoch 10/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5130 - root_mean_squared_error: 0.7033 - val_loss: 6.0095 - val_root_mean_squared_error: 0.7230
# Epoch 11/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5061 - root_mean_squared_error: 0.7034 - val_loss: 6.0326 - val_root_mean_squared_error: 0.7216
# Epoch 12/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4983 - root_mean_squared_error: 0.6987 - val_loss: 6.0433 - val_root_mean_squared_error: 0.7259
# Epoch 13/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5046 - root_mean_squared_error: 0.7033 - val_loss: 6.0388 - val_root_mean_squared_error: 0.7216
# Epoch 14/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5054 - root_mean_squared_error: 0.7021 - val_loss: 6.0775 - val_root_mean_squared_error: 0.7264
# Epoch 15/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4915 - root_mean_squared_error: 0.6981 - val_loss: 6.0585 - val_root_mean_squared_error: 0.7245
# Epoch 16/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.5025 - root_mean_squared_error: 0.7003 - val_loss: 6.0333 - val_root_mean_squared_error: 0.7244
# Epoch 17/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5058 - root_mean_squared_error: 0.7007 - val_loss: 6.0351 - val_root_mean_squared_error: 0.7255
# Epoch 18/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5011 - root_mean_squared_error: 0.6994 - val_loss: 6.0170 - val_root_mean_squared_error: 0.7228
# Epoch 19/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4846 - root_mean_squared_error: 0.7032 - val_loss: 6.1014 - val_root_mean_squared_error: 0.7238
# Epoch 20/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.5049 - root_mean_squared_error: 0.6986 - val_loss: 6.0198 - val_root_mean_squared_error: 0.7236
# Epoch 21/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4920 - root_mean_squared_error: 0.7007 - val_loss: 6.0755 - val_root_mean_squared_error: 0.7205
# Epoch 22/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4914 - root_mean_squared_error: 0.7017 - val_loss: 6.0120 - val_root_mean_squared_error: 0.7249
# Epoch 23/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.5001 - root_mean_squared_error: 0.7005 - val_loss: 6.0603 - val_root_mean_squared_error: 0.7330
# Epoch 24/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4924 - root_mean_squared_error: 0.7044 - val_loss: 6.0848 - val_root_mean_squared_error: 0.7290
# Epoch 25/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4957 - root_mean_squared_error: 0.7021 - val_loss: 6.0552 - val_root_mean_squared_error: 0.7239
# Epoch 26/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4830 - root_mean_squared_error: 0.7020 - val_loss: 5.9661 - val_root_mean_squared_error: 0.7235
# Epoch 27/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4964 - root_mean_squared_error: 0.7017 - val_loss: 6.0851 - val_root_mean_squared_error: 0.7276
# Epoch 28/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4876 - root_mean_squared_error: 0.6982 - val_loss: 6.0475 - val_root_mean_squared_error: 0.7220
# Epoch 29/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4826 - root_mean_squared_error: 0.6982 - val_loss: 6.0056 - val_root_mean_squared_error: 0.7255
# Epoch 30/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4845 - root_mean_squared_error: 0.6967 - val_loss: 5.9997 - val_root_mean_squared_error: 0.7218
# Epoch 31/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4838 - root_mean_squared_error: 0.7036 - val_loss: 6.0498 - val_root_mean_squared_error: 0.7233
# Epoch 32/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4995 - root_mean_squared_error: 0.7039 - val_loss: 6.0370 - val_root_mean_squared_error: 0.7269
# Epoch 33/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4924 - root_mean_squared_error: 0.7005 - val_loss: 6.0046 - val_root_mean_squared_error: 0.7239
# Epoch 34/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4836 - root_mean_squared_error: 0.6999 - val_loss: 6.0525 - val_root_mean_squared_error: 0.7225
# Epoch 35/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4864 - root_mean_squared_error: 0.6989 - val_loss: 5.9956 - val_root_mean_squared_error: 0.7270
# Epoch 36/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4802 - root_mean_squared_error: 0.6995 - val_loss: 6.0092 - val_root_mean_squared_error: 0.7253
# Epoch 37/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4897 - root_mean_squared_error: 0.7009 - val_loss: 6.0576 - val_root_mean_squared_error: 0.7323
# Epoch 38/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4838 - root_mean_squared_error: 0.7005 - val_loss: 6.0498 - val_root_mean_squared_error: 0.7253
# Epoch 39/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4906 - root_mean_squared_error: 0.6984 - val_loss: 6.0492 - val_root_mean_squared_error: 0.7273
# Epoch 40/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4905 - root_mean_squared_error: 0.7014 - val_loss: 6.0196 - val_root_mean_squared_error: 0.7202
# Epoch 41/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4815 - root_mean_squared_error: 0.7003 - val_loss: 6.0194 - val_root_mean_squared_error: 0.7241
# Epoch 42/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4701 - root_mean_squared_error: 0.7027 - val_loss: 6.0873 - val_root_mean_squared_error: 0.7250
# Epoch 43/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4739 - root_mean_squared_error: 0.6968 - val_loss: 6.0456 - val_root_mean_squared_error: 0.7289
# Epoch 44/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4778 - root_mean_squared_error: 0.6991 - val_loss: 6.0687 - val_root_mean_squared_error: 0.7188
# Epoch 45/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4780 - root_mean_squared_error: 0.6997 - val_loss: 6.0243 - val_root_mean_squared_error: 0.7273
# Epoch 46/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4759 - root_mean_squared_error: 0.7003 - val_loss: 6.0386 - val_root_mean_squared_error: 0.7247
# Epoch 47/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4743 - root_mean_squared_error: 0.7002 - val_loss: 6.0230 - val_root_mean_squared_error: 0.7211
# Epoch 48/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4666 - root_mean_squared_error: 0.6990 - val_loss: 6.0555 - val_root_mean_squared_error: 0.7268
# Epoch 49/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4727 - root_mean_squared_error: 0.7001 - val_loss: 6.0220 - val_root_mean_squared_error: 0.7231
# Epoch 50/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4633 - root_mean_squared_error: 0.7010 - val_loss: 6.1459 - val_root_mean_squared_error: 0.7292
# Epoch 51/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4398 - root_mean_squared_error: 0.6978 - val_loss: 6.0390 - val_root_mean_squared_error: 0.7222
# Epoch 52/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4484 - root_mean_squared_error: 0.6991 - val_loss: 6.1701 - val_root_mean_squared_error: 0.7320
# Epoch 53/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4471 - root_mean_squared_error: 0.6994 - val_loss: 5.9934 - val_root_mean_squared_error: 0.7223
# Epoch 54/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4402 - root_mean_squared_error: 0.6969 - val_loss: 6.1260 - val_root_mean_squared_error: 0.7266
# Epoch 55/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4355 - root_mean_squared_error: 0.6949 - val_loss: 6.1485 - val_root_mean_squared_error: 0.7281
# Epoch 56/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4307 - root_mean_squared_error: 0.6960 - val_loss: 5.9975 - val_root_mean_squared_error: 0.7196
# Epoch 57/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4384 - root_mean_squared_error: 0.6982 - val_loss: 6.1030 - val_root_mean_squared_error: 0.7275
# Epoch 58/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.4211 - root_mean_squared_error: 0.6969 - val_loss: 6.0830 - val_root_mean_squared_error: 0.7235
# Epoch 59/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.3997 - root_mean_squared_error: 0.6949 - val_loss: 6.0890 - val_root_mean_squared_error: 0.7293
# Epoch 60/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.4010 - root_mean_squared_error: 0.6956 - val_loss: 5.9479 - val_root_mean_squared_error: 0.7250
# Epoch 61/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.3740 - root_mean_squared_error: 0.6961 - val_loss: 6.0020 - val_root_mean_squared_error: 0.7224
# Epoch 62/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.3723 - root_mean_squared_error: 0.6907 - val_loss: 6.1059 - val_root_mean_squared_error: 0.7268
# Epoch 63/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.3375 - root_mean_squared_error: 0.6944 - val_loss: 6.0395 - val_root_mean_squared_error: 0.7296
# Epoch 64/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.3261 - root_mean_squared_error: 0.6892 - val_loss: 5.8828 - val_root_mean_squared_error: 0.7206
# Epoch 65/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.3015 - root_mean_squared_error: 0.6912 - val_loss: 5.9164 - val_root_mean_squared_error: 0.7192
# Epoch 66/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.2837 - root_mean_squared_error: 0.6873 - val_loss: 5.9686 - val_root_mean_squared_error: 0.7200
# Epoch 67/200
# 51/51 [==============================] - 0s 7ms/step - loss: 5.2485 - root_mean_squared_error: 0.6865 - val_loss: 5.9545 - val_root_mean_squared_error: 0.7183
# Epoch 68/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.1934 - root_mean_squared_error: 0.6819 - val_loss: 5.7869 - val_root_mean_squared_error: 0.7135
# Epoch 69/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.1986 - root_mean_squared_error: 0.6831 - val_loss: 5.7561 - val_root_mean_squared_error: 0.7086
# Epoch 70/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.1548 - root_mean_squared_error: 0.6802 - val_loss: 5.8911 - val_root_mean_squared_error: 0.7133
# Epoch 71/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.0937 - root_mean_squared_error: 0.6788 - val_loss: 5.7801 - val_root_mean_squared_error: 0.7127
# Epoch 72/200
# 51/51 [==============================] - 0s 6ms/step - loss: 5.0351 - root_mean_squared_error: 0.6754 - val_loss: 5.7240 - val_root_mean_squared_error: 0.7077
# Epoch 73/200
# 51/51 [==============================] - 0s 7ms/step - loss: 4.9933 - root_mean_squared_error: 0.6720 - val_loss: 5.7559 - val_root_mean_squared_error: 0.7089
# Epoch 74/200
# 51/51 [==============================] - 0s 6ms/step - loss: 4.9132 - root_mean_squared_error: 0.6676 - val_loss: 5.4489 - val_root_mean_squared_error: 0.6958
# Epoch 75/200
# 51/51 [==============================] - 0s 6ms/step - loss: 4.8287 - root_mean_squared_error: 0.6638 - val_loss: 5.5602 - val_root_mean_squared_error: 0.7016
# Epoch 76/200
# 51/51 [==============================] - 0s 6ms/step - loss: 4.8489 - root_mean_squared_error: 0.6658 - val_loss: 5.4458 - val_root_mean_squared_error: 0.6966
# Epoch 77/200
# 51/51 [==============================] - 0s 6ms/step - loss: 4.7630 - root_mean_squared_error: 0.6615 - val_loss: 5.3824 - val_root_mean_squared_error: 0.6918
# Epoch 78/200
# 51/51 [==============================] - 0s 8ms/step - loss: 4.6918 - root_mean_squared_error: 0.6551 - val_loss: 5.2920 - val_root_mean_squared_error: 0.6893
# Epoch 79/200
# ...
# Epoch 109/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2228 - root_mean_squared_error: 0.2659 - val_loss: 1.5403 - val_root_mean_squared_error: 0.3103
# Epoch 110/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1934 - root_mean_squared_error: 0.2631 - val_loss: 1.7330 - val_root_mean_squared_error: 0.3438
# Epoch 111/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2123 - root_mean_squared_error: 0.2646 - val_loss: 2.0482 - val_root_mean_squared_error: 0.3370
# Epoch 112/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2688 - root_mean_squared_error: 0.2675 - val_loss: 2.4398 - val_root_mean_squared_error: 0.3944
# Epoch 113/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2463 - root_mean_squared_error: 0.2631 - val_loss: 1.7872 - val_root_mean_squared_error: 0.3492
# Epoch 114/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2180 - root_mean_squared_error: 0.2585 - val_loss: 2.0364 - val_root_mean_squared_error: 0.3807
# Epoch 115/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2917 - root_mean_squared_error: 0.2689 - val_loss: 2.3782 - val_root_mean_squared_error: 0.4138
# Epoch 116/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1760 - root_mean_squared_error: 0.2603 - val_loss: 1.9292 - val_root_mean_squared_error: 0.3446
# Epoch 117/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1928 - root_mean_squared_error: 0.2650 - val_loss: 1.6778 - val_root_mean_squared_error: 0.3466
# Epoch 118/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1953 - root_mean_squared_error: 0.2581 - val_loss: 1.7776 - val_root_mean_squared_error: 0.3379
# Epoch 119/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1977 - root_mean_squared_error: 0.2564 - val_loss: 2.4915 - val_root_mean_squared_error: 0.3970
# Epoch 120/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1725 - root_mean_squared_error: 0.2548 - val_loss: 2.6301 - val_root_mean_squared_error: 0.4147
# Epoch 121/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2166 - root_mean_squared_error: 0.2648 - val_loss: 1.8358 - val_root_mean_squared_error: 0.3433
# Epoch 122/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2061 - root_mean_squared_error: 0.2652 - val_loss: 1.8519 - val_root_mean_squared_error: 0.3493
# Epoch 123/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1603 - root_mean_squared_error: 0.2623 - val_loss: 2.1960 - val_root_mean_squared_error: 0.3724
# Epoch 124/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2486 - root_mean_squared_error: 0.2652 - val_loss: 2.0810 - val_root_mean_squared_error: 0.3761
# Epoch 125/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2041 - root_mean_squared_error: 0.2604 - val_loss: 1.5604 - val_root_mean_squared_error: 0.3259
# Epoch 126/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2027 - root_mean_squared_error: 0.2592 - val_loss: 2.1842 - val_root_mean_squared_error: 0.3721
# Epoch 127/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2048 - root_mean_squared_error: 0.2597 - val_loss: 2.0038 - val_root_mean_squared_error: 0.3578
# Epoch 128/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1956 - root_mean_squared_error: 0.2618 - val_loss: 1.6748 - val_root_mean_squared_error: 0.3342
# Epoch 129/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2131 - root_mean_squared_error: 0.2608 - val_loss: 2.1290 - val_root_mean_squared_error: 0.3665
# Epoch 130/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1838 - root_mean_squared_error: 0.2669 - val_loss: 1.9518 - val_root_mean_squared_error: 0.3586
# Epoch 131/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.2407 - root_mean_squared_error: 0.2633 - val_loss: 2.1122 - val_root_mean_squared_error: 0.3685
# Epoch 132/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1418 - root_mean_squared_error: 0.2552 - val_loss: 2.1717 - val_root_mean_squared_error: 0.3687
# Epoch 133/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2308 - root_mean_squared_error: 0.2705 - val_loss: 2.1817 - val_root_mean_squared_error: 0.3748
# Epoch 134/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1985 - root_mean_squared_error: 0.2583 - val_loss: 2.0003 - val_root_mean_squared_error: 0.3657
# Epoch 135/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1621 - root_mean_squared_error: 0.2584 - val_loss: 1.9242 - val_root_mean_squared_error: 0.3609
# Epoch 136/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1095 - root_mean_squared_error: 0.2533 - val_loss: 1.9872 - val_root_mean_squared_error: 0.3620
# Epoch 137/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1798 - root_mean_squared_error: 0.2600 - val_loss: 2.1070 - val_root_mean_squared_error: 0.3691
# Epoch 138/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1680 - root_mean_squared_error: 0.2553 - val_loss: 2.3153 - val_root_mean_squared_error: 0.3758
# Epoch 139/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1919 - root_mean_squared_error: 0.2618 - val_loss: 2.1090 - val_root_mean_squared_error: 0.3617
# Epoch 140/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1485 - root_mean_squared_error: 0.2536 - val_loss: 2.0723 - val_root_mean_squared_error: 0.3482
# Epoch 141/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1415 - root_mean_squared_error: 0.2539 - val_loss: 2.2735 - val_root_mean_squared_error: 0.3739
# Epoch 142/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1151 - root_mean_squared_error: 0.2559 - val_loss: 2.0897 - val_root_mean_squared_error: 0.3592
# Epoch 143/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1225 - root_mean_squared_error: 0.2531 - val_loss: 1.8927 - val_root_mean_squared_error: 0.3410
# Epoch 144/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1451 - root_mean_squared_error: 0.2499 - val_loss: 1.7537 - val_root_mean_squared_error: 0.3367
# Epoch 145/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1849 - root_mean_squared_error: 0.2622 - val_loss: 2.3901 - val_root_mean_squared_error: 0.3953
# Epoch 146/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1708 - root_mean_squared_error: 0.2542 - val_loss: 2.3561 - val_root_mean_squared_error: 0.3920
# Epoch 147/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1259 - root_mean_squared_error: 0.2512 - val_loss: 2.4128 - val_root_mean_squared_error: 0.3703
# Epoch 148/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1533 - root_mean_squared_error: 0.2557 - val_loss: 2.0680 - val_root_mean_squared_error: 0.3399
# Epoch 149/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0716 - root_mean_squared_error: 0.2496 - val_loss: 1.9371 - val_root_mean_squared_error: 0.3759
# Epoch 150/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1442 - root_mean_squared_error: 0.2559 - val_loss: 2.3866 - val_root_mean_squared_error: 0.3749
# Epoch 151/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.0944 - root_mean_squared_error: 0.2532 - val_loss: 2.6726 - val_root_mean_squared_error: 0.3960
# Epoch 152/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.0869 - root_mean_squared_error: 0.2442 - val_loss: 1.8946 - val_root_mean_squared_error: 0.3652
# Epoch 153/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1217 - root_mean_squared_error: 0.2596 - val_loss: 2.1890 - val_root_mean_squared_error: 0.3660
# Epoch 154/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1007 - root_mean_squared_error: 0.2515 - val_loss: 1.7735 - val_root_mean_squared_error: 0.3226
# Epoch 155/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0628 - root_mean_squared_error: 0.2408 - val_loss: 1.6409 - val_root_mean_squared_error: 0.3197
# Epoch 156/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1541 - root_mean_squared_error: 0.2540 - val_loss: 1.5834 - val_root_mean_squared_error: 0.3214
# Epoch 157/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1343 - root_mean_squared_error: 0.2518 - val_loss: 1.6761 - val_root_mean_squared_error: 0.3119
# Epoch 158/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0796 - root_mean_squared_error: 0.2464 - val_loss: 1.7000 - val_root_mean_squared_error: 0.3170
# Epoch 159/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0812 - root_mean_squared_error: 0.2470 - val_loss: 1.8229 - val_root_mean_squared_error: 0.3293
# Epoch 160/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1173 - root_mean_squared_error: 0.2498 - val_loss: 2.0422 - val_root_mean_squared_error: 0.3567
# Epoch 161/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1239 - root_mean_squared_error: 0.2525 - val_loss: 1.9046 - val_root_mean_squared_error: 0.3498
# Epoch 162/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1239 - root_mean_squared_error: 0.2537 - val_loss: 1.7150 - val_root_mean_squared_error: 0.3347
# Epoch 163/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1176 - root_mean_squared_error: 0.2561 - val_loss: 1.7635 - val_root_mean_squared_error: 0.3162
# Epoch 164/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0897 - root_mean_squared_error: 0.2405 - val_loss: 1.6694 - val_root_mean_squared_error: 0.3351
# Epoch 165/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0941 - root_mean_squared_error: 0.2539 - val_loss: 1.6183 - val_root_mean_squared_error: 0.3209
# Epoch 166/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0889 - root_mean_squared_error: 0.2445 - val_loss: 1.8752 - val_root_mean_squared_error: 0.3291
# Epoch 167/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0208 - root_mean_squared_error: 0.2407 - val_loss: 1.5285 - val_root_mean_squared_error: 0.3157
# Epoch 168/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.1091 - root_mean_squared_error: 0.2566 - val_loss: 1.4863 - val_root_mean_squared_error: 0.3068
# Epoch 169/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0709 - root_mean_squared_error: 0.2428 - val_loss: 2.0517 - val_root_mean_squared_error: 0.3367
# Epoch 170/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0335 - root_mean_squared_error: 0.2362 - val_loss: 2.1931 - val_root_mean_squared_error: 0.3545
# Epoch 171/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9958 - root_mean_squared_error: 0.2315 - val_loss: 1.4702 - val_root_mean_squared_error: 0.3051
# Epoch 172/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0382 - root_mean_squared_error: 0.2441 - val_loss: 1.9575 - val_root_mean_squared_error: 0.3465
# Epoch 173/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0800 - root_mean_squared_error: 0.2434 - val_loss: 1.6902 - val_root_mean_squared_error: 0.3350
# Epoch 174/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0064 - root_mean_squared_error: 0.2374 - val_loss: 1.6164 - val_root_mean_squared_error: 0.3045
# Epoch 175/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0142 - root_mean_squared_error: 0.2405 - val_loss: 1.8917 - val_root_mean_squared_error: 0.3457
# Epoch 176/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9674 - root_mean_squared_error: 0.2352 - val_loss: 2.3222 - val_root_mean_squared_error: 0.3506
# Epoch 177/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0315 - root_mean_squared_error: 0.2394 - val_loss: 2.1046 - val_root_mean_squared_error: 0.3619
# Epoch 178/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9708 - root_mean_squared_error: 0.2347 - val_loss: 1.8189 - val_root_mean_squared_error: 0.3172
# Epoch 179/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0107 - root_mean_squared_error: 0.2417 - val_loss: 2.1579 - val_root_mean_squared_error: 0.3343
# Epoch 180/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9437 - root_mean_squared_error: 0.2351 - val_loss: 2.1209 - val_root_mean_squared_error: 0.3151
# Epoch 181/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9521 - root_mean_squared_error: 0.2302 - val_loss: 1.7802 - val_root_mean_squared_error: 0.3118
# Epoch 182/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0352 - root_mean_squared_error: 0.2355 - val_loss: 2.0114 - val_root_mean_squared_error: 0.3560
# Epoch 183/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0074 - root_mean_squared_error: 0.2352 - val_loss: 1.8555 - val_root_mean_squared_error: 0.3211
# Epoch 184/200
# 51/51 [==============================] - 0s 8ms/step - loss: 1.0500 - root_mean_squared_error: 0.2376 - val_loss: 2.0117 - val_root_mean_squared_error: 0.3438
# Epoch 185/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9667 - root_mean_squared_error: 0.2389 - val_loss: 1.9060 - val_root_mean_squared_error: 0.3396
# Epoch 186/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.9983 - root_mean_squared_error: 0.2335 - val_loss: 1.5448 - val_root_mean_squared_error: 0.3249
# Epoch 187/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9717 - root_mean_squared_error: 0.2368 - val_loss: 1.7881 - val_root_mean_squared_error: 0.3245
# Epoch 188/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0090 - root_mean_squared_error: 0.2369 - val_loss: 1.5000 - val_root_mean_squared_error: 0.2983
# Epoch 189/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9080 - root_mean_squared_error: 0.2265 - val_loss: 1.5278 - val_root_mean_squared_error: 0.3110
# Epoch 190/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9038 - root_mean_squared_error: 0.2213 - val_loss: 2.4318 - val_root_mean_squared_error: 0.3456
# Epoch 191/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9574 - root_mean_squared_error: 0.2253 - val_loss: 1.7335 - val_root_mean_squared_error: 0.3151
# Epoch 192/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.9742 - root_mean_squared_error: 0.2319 - val_loss: 1.5023 - val_root_mean_squared_error: 0.3065
# Epoch 193/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9427 - root_mean_squared_error: 0.2255 - val_loss: 1.6838 - val_root_mean_squared_error: 0.2939
# Epoch 194/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.9314 - root_mean_squared_error: 0.2335 - val_loss: 1.6487 - val_root_mean_squared_error: 0.3278
# Epoch 195/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9213 - root_mean_squared_error: 0.2245 - val_loss: 1.7532 - val_root_mean_squared_error: 0.3015
# Epoch 196/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9206 - root_mean_squared_error: 0.2233 - val_loss: 1.6137 - val_root_mean_squared_error: 0.3053
# Epoch 197/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9070 - root_mean_squared_error: 0.2170 - val_loss: 1.4725 - val_root_mean_squared_error: 0.2802
# Epoch 198/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9586 - root_mean_squared_error: 0.2238 - val_loss: 2.2350 - val_root_mean_squared_error: 0.3303
# Epoch 199/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9747 - root_mean_squared_error: 0.2311 - val_loss: 1.6766 - val_root_mean_squared_error: 0.3166
# Epoch 200/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.9578 - root_mean_squared_error: 0.2270 - val_loss: 1.6983 - val_root_mean_squared_error: 0.3282

# %%
# Prediction on test and train data with NN models
for k in params.keys():
    print('Model: %s' % (k))
    model = params[k]['model']

    params[k]['train_pd'] = model.predict(x_train, verbose = 1)
    params[k]['test_pd'] = model.predict(x_test, verbose = 1)
# Out:
# Model: bnn_a1
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_a2
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_a3
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_b1
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_b2
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_b3
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_c1
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_c2
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_c3
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step

# %%
# Calculate prediction means and stddevs
for k in params.keys():
    params[k]['train_means'] = np.array([np.mean(x) for x in params[k]['train_pd']])
    params[k]['train_stdev'] = np.array([np.std(x) for x in params[k]['train_pd']])
    params[k]['test_means'] = np.array([np.mean(x) for x in params[k]['test_pd']])
    params[k]['test_stdev'] = np.array([np.std(x) for x in params[k]['test_pd']])

# %%
# Calculate test, train RMSE
for k in params.keys():
    params[k]['RMSE_train'] = mean_squared_error(y_train, params[k]['train_means'], squared = False)
    params[k]['RMSE_test'] = mean_squared_error(y_test, params[k]['test_means'], squared = False)

# %%
# Average deviations
for k in params.keys():
    params[k]['avg_train_stdev'] = params[k]['train_stdev'].mean()
    params[k]['avg_test_stdev'] = params[k]['test_stdev'].mean()

# %%
# Metrics

for k in params.keys():
    print('Model: %s' % (params[k]['label']))
    print('\tTrain RMSE: %f' % params[k]['RMSE_train'])
    print('\tTest RMSE: %f' % params[k]['RMSE_test'])
    print('\tAvg Test StDev: %f' % params[k]['avg_train_stdev'])
    print('\tAvg Train StDev: %f' % params[k]['avg_test_stdev'])
# Out:
# Model: BNN A - lr=1e-3
# 	Train RMSE: 0.166641
# 	Test RMSE: 0.316501
# 	Avg Test StDev: 0.063934
# 	Avg Train StDev: 0.154941
# Model: BNN A - lr=5e-4
# 	Train RMSE: 0.199982
# 	Test RMSE: 0.249885
# 	Avg Test StDev: 0.087259
# 	Avg Train StDev: 0.149590
# Model: BNN A - lr=5e-3
# 	Train RMSE: 0.115723
# 	Test RMSE: 0.295446
# 	Avg Test StDev: 0.033071
# 	Avg Train StDev: 0.076561
# Model: BNN B - lr=1e-3
# 	Train RMSE: 0.181096
# 	Test RMSE: 0.259919
# 	Avg Test StDev: 0.070322
# 	Avg Train StDev: 0.139254
# Model: BNN B - lr=5e-4
# 	Train RMSE: 0.192148
# 	Test RMSE: 0.247137
# 	Avg Test StDev: 0.083656
# 	Avg Train StDev: 0.142098
# Model: BNN B - lr=5e-3
# 	Train RMSE: 0.128265
# 	Test RMSE: 0.233349
# 	Avg Test StDev: 0.030479
# 	Avg Train StDev: 0.078815
# Model: BNN C - lr=1e-3
# 	Train RMSE: 0.181421
# 	Test RMSE: 0.263227
# 	Avg Test StDev: 0.071871
# 	Avg Train StDev: 0.151401
# Model: BNN C - lr=5e-4
# 	Train RMSE: 0.200114
# 	Test RMSE: 0.233081
# 	Avg Test StDev: 0.089149
# 	Avg Train StDev: 0.129612
# Model: BNN C - lr=5e-3
# 	Train RMSE: 0.161476
# 	Test RMSE: 0.224101
# 	Avg Test StDev: 0.051137
# 	Avg Train StDev: 0.104321

# %%
# Plot training loss by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(1, 0, 9))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['loss'], color = colors[i], label = params[k]['label'], alpha = 0.8)
    i += 1
    
#plt.xscale('log')
plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Epoches', fontsize = 12)
plt.ylabel('Loss (-log likelihood)', fontsize = 12)
plt.title('Training Loss By Epoch', fontsize = 18)

plt.show()

# %%
# Plot training error by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(1, 0, 9))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['root_mean_squared_error'], color = colors[i], label = params[k]['label'], alpha = 0.8)
    i += 1
    
plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Epoches', fontsize = 12)
plt.ylabel('Error (RMSE)', fontsize = 12)
plt.title('Training Error By Epoch', fontsize = 18)

plt.show()

# %%
# Plot validation loss by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(1, 0, 9))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['val_loss'], color = colors[i], label = params[k]['label'], alpha = 0.8)
    i += 1
    
plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Epoches', fontsize = 12)
plt.ylabel('Loss (-log likelihood)', fontsize = 12)
plt.title('Validation Loss By Epoch', fontsize = 18)

plt.show()

# %%
# Plot validation error by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(1, 0, 9))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['val_root_mean_squared_error'], color = colors[i], label = params[k]['label'], alpha = 0.8)
    i += 1
    
plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Epoches', fontsize = 12)
plt.ylabel('Error (RMSE)', fontsize = 12)
plt.title('Validation Error By Epoch', fontsize = 18)

plt.show()

# %%
# Plot distributions
fig, ax = plt.subplots(3, 3, figsize = (30, 12), dpi = 100)
colors = pl.cm.jet(np.linspace(1, 0, 18))
c = 0

k = list(params.keys())

# Plot train
for row in ax:
    for col in row:
        col.hist(params[k[c]]['train_means'], bins = 30, color = colors[c], alpha = 0.5, label = 'Train')
        col.set_title(params[k[c]]['label'])
        c += 1

# Plot test
for row in ax:
    for col in row:
        col.hist(params[k[c-9]]['test_means'], bins = 30, color = colors[c], alpha = 0.5, label = 'Test')
        col.set_title(params[k[c-9]]['label'])
        col.legend(loc = 'best')
        c += 1


# Plot test
fig.suptitle('Prediction Distributions', fontsize = 24)

plt.show()
