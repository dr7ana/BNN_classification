# %%
# standard
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pl

# os
import os

# sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# tf
import tensorflow as tf
import tensorflow_probability as tfp
tfd = tfp.distributions
tfb = tfp.bijectors

# keras
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Layer, Input, Activation, Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras import optimizers
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K
from keras.regularizers import l1,l2
from keras.utils.vis_utils import plot_model

# %%
# Import data
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Make pd df
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Mushroom Classification Project/mushrooms.csv')

# %% [markdown]
# #### Data Topology:
#
# -	cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
# -	cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
# -	cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y
# -	bruises: bruises=t,no=f
# -	odor: almond=a,anise=l,creosote=c,fishy=y,foul=f,musty=m,none=n,pungent=p,spicy=s
# -	gill-attachment: attached=a,descending=d,free=f,notched=n
# -	gill-spacing: close=c,crowded=w,distant=d
# -	gill-size: broad=b,narrow=n
# -	gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e,white=w,yellow=y
# -	stalk-shape: enlarging=e,tapering=t
# -	stalk-root: bulbous=b,club=c,cup=u,equal=e,rhizomorphs=z,rooted=r,missing=?
# -	stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
# -	stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
# -	stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
# -	stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
# -	veil-type: partial=p,universal=u
# -	veil-color: brown=n,orange=o,white=w,yellow=y
# -	ring-number: none=n,one=o,two=t
# -	ring-type: cobwebby=c,evanescent=e,flaring=f,large=l,none=n,pendant=p,sheathing=s,zone=z
# -	spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r,orange=o,purple=u,white=w,yellow=y
# -	population: abundant=a,clustered=c,numerous=n,scattered=s,several=v,solitary=y
# -	habitat: grasses=g,leaves=l,meadows=m,paths=p,urban=u,waste=w,woods=d

# %%
# Categorical encoding

for feat in df.columns:
    # extract unique column values
    vals = np.unique(df[feat].values)
    # fit labelencoder
    le = LabelEncoder()
    le.fit(df[feat])
    # transform dataset
    df[feat] = le.transform(df[feat])

# %%
# Extract list of training features
tfeatures = np.array(df.columns)[1:]
features = np.array(df.columns)

# %%
# Split into train/target
_target = df.pop('class')
_train = df

# %%
# Train size
train_size = 6499

# Make train/test data
x_train = {}
x_test = {}
y_train = []
y_test = []

# %%
# Populate x_train, x_test
for f in tfeatures:
    x_train[f] = _train[f][:train_size+1]
    x_test[f] = _train[f][train_size:]

# %%
# Populate y_train, y_test
y_train = _target[:train_size+1]
y_test = _target[train_size:]

# %%
# Custom activation function
def swish(x):
    return (K.sigmoid(x) * x)

get_custom_objects().update({'swish': Activation(swish)})

# %%
# Custom loss function
def neg_log_likelihood(targets, estimate):
    return -estimate.log_prob(targets)

# %%
# BNN Model

# Prior weights will remain fixed and untrained
#   mean = 0
#   std-dev = 1
def prior_weights_model(kernel_size, bias_size, dtype = None):
    units = kernel_size + bias_size
    pw = Sequential()
    pw.add(
        tfp.layers.DistributionLambda(
            lambda x: tfd.MultivariateNormalDiag(loc = tf.zeros(units), 
                                                 scale_diag = tf.ones(units) )
        ) 
    )
    return pw

# Posterior weights will be trained and unfixed
#   learnable params are mean, variance, and covariance
def posterior_inference_model(kernel_size, bias_size, dtype = None):
    units = kernel_size + bias_size
    pi = Sequential()
    pi.add(
        tfp.layers.VariableLayer(
            tfp.layers.MultivariateNormalTriL.params_size(units), dtype = dtype
        )
    )
    pi.add(
        tfp.layers.MultivariateNormalTriL(units)
    )
    return pi

# This function will produce an input tensor for each feature extracted from the df
#   keras.layers.Input produces a keras tensor with a specific feature name
#   this will allow us to later quantify inference for each feature
def populate_input_tensors(_features = tfeatures):
    inputs = {}
    for f in _features:
        inputs[f] = Input(name = f, shape = (1,), dtype = tf.float32)
    return inputs

# training_size = len(x_train)
def _BNN(n_units = 2, lr = 0.001, training_size = 6500, hidden_units = 10, activ = 'sigmoid'):
    input_layers = populate_input_tensors()
    feature_layers = keras.layers.concatenate( list(input_layers.values()) )
    feature_layers = keras.layers.BatchNormalization()(feature_layers)

    for u in np.full(shape = n_units, fill_value = hidden_units):
        feature_layers = tfp.layers.DenseVariational(
            units = u,
            make_posterior_fn = posterior_inference_model,
            make_prior_fn = prior_weights_model,
            kl_weight = 1 / training_size,
            activation = activ)(feature_layers)

    # Probabilistic output model
    #   Dense layer: used to produce distribution parameters
    #   IndependentBernoulli: used for binary classification
    dist_params = Dense(units = 2)(feature_layers)
    output_layers = tfp.layers.IndependentBernoulli(2)(dist_params)

    model = keras.Model(inputs = input_layers, outputs = output_layers)
    model.compile(optimizer = keras.optimizers.RMSprop(learning_rate = lr), 
                  metrics = [keras.metrics.RootMeanSquaredError()], 
                  loss = neg_log_likelihood)
    return model

# %%
params = {
    'bnn_a1':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':6, 'lr':0.005, 'batch_size':64, 'activ':'sigmoid', 'label':'BNN A - 64', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_a2':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':6, 'lr':0.005, 'batch_size':128, 'activ':'sigmoid', 'label':'BNN A - 128', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_a3':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':6, 'lr':0.005, 'batch_size':256, 'activ':'sigmoid', 'label':'BNN A - 256', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_a4':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':6, 'lr':0.005, 'batch_size':512, 'activ':'sigmoid', 'label':'BNN A - 512', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_b1':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':8, 'lr':0.005, 'batch_size':64, 'activ':'sigmoid', 'label':'BNN B - 64', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_b2':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':8, 'lr':0.005, 'batch_size':128, 'activ':'sigmoid', 'label':'BNN B - 128', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_b3':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':8, 'lr':0.005, 'batch_size':256, 'activ':'sigmoid', 'label':'BNN B - 256', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''},
    'bnn_b4':{'model':'', 'function':_BNN, 'n_units':2, 'hidden_units':8, 'lr':0.005, 'batch_size':512, 'activ':'sigmoid', 'label':'BNN B - 512', 'history':'', 'RMSE_train':'', 'RMSE_test':'', 'predict':'', 'cv_results':''}
}

# %%
# Parameters
n_epoches = 200

# %%
# Train cross-validated NN model
for k in params.keys():
    tf.random.set_seed(0)
    model = params[k]['function'](n_units = params[k]['n_units'], lr = params[k]['lr'], training_size = len(y_train), hidden_units = params[k]['hidden_units'])
    params[k]['history'] = model.fit(x = x_train, y = y_train, validation_data = (x_test, y_test), epochs = n_epoches, batch_size = params[k]['batch_size'], shuffle = True)
    params[k]['model'] = model
# Out:
# Epoch 1/200
# 102/102 [==============================] - 7s 14ms/step - loss: 1.3899 - root_mean_squared_error: 0.7030 - val_loss: 1.5079 - val_root_mean_squared_error: 0.7185
# Epoch 2/200
# 102/102 [==============================] - 1s 6ms/step - loss: 1.3750 - root_mean_squared_error: 0.6995 - val_loss: 1.4750 - val_root_mean_squared_error: 0.7145
# Epoch 3/200
# 102/102 [==============================] - 1s 7ms/step - loss: 1.3451 - root_mean_squared_error: 0.6969 - val_loss: 1.3967 - val_root_mean_squared_error: 0.7021
# Epoch 4/200
# 102/102 [==============================] - 1s 7ms/step - loss: 1.2211 - root_mean_squared_error: 0.6598 - val_loss: 1.1896 - val_root_mean_squared_error: 0.6537
# Epoch 5/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.9653 - root_mean_squared_error: 0.5922 - val_loss: 0.7573 - val_root_mean_squared_error: 0.5329
# Epoch 6/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.7186 - root_mean_squared_error: 0.5039 - val_loss: 0.6776 - val_root_mean_squared_error: 0.4710
# Epoch 7/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.5912 - root_mean_squared_error: 0.4266 - val_loss: 0.4639 - val_root_mean_squared_error: 0.4072
# Epoch 8/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.5276 - root_mean_squared_error: 0.3868 - val_loss: 0.4740 - val_root_mean_squared_error: 0.3762
# Epoch 9/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.5119 - root_mean_squared_error: 0.3785 - val_loss: 0.4538 - val_root_mean_squared_error: 0.3637
# Epoch 10/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4846 - root_mean_squared_error: 0.3572 - val_loss: 0.3792 - val_root_mean_squared_error: 0.3582
# Epoch 11/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.4546 - root_mean_squared_error: 0.3476 - val_loss: 0.4768 - val_root_mean_squared_error: 0.3477
# Epoch 12/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4312 - root_mean_squared_error: 0.3292 - val_loss: 0.5289 - val_root_mean_squared_error: 0.3729
# Epoch 13/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.4397 - root_mean_squared_error: 0.3286 - val_loss: 0.4764 - val_root_mean_squared_error: 0.3469
# Epoch 14/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.4263 - root_mean_squared_error: 0.3149 - val_loss: 0.4361 - val_root_mean_squared_error: 0.3608
# Epoch 15/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4120 - root_mean_squared_error: 0.3171 - val_loss: 0.4145 - val_root_mean_squared_error: 0.3319
# Epoch 16/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.4025 - root_mean_squared_error: 0.3209 - val_loss: 0.3621 - val_root_mean_squared_error: 0.3157
# Epoch 17/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.4024 - root_mean_squared_error: 0.3129 - val_loss: 0.4055 - val_root_mean_squared_error: 0.3337
# Epoch 18/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3980 - root_mean_squared_error: 0.3067 - val_loss: 0.3577 - val_root_mean_squared_error: 0.3078
# Epoch 19/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3872 - root_mean_squared_error: 0.3112 - val_loss: 0.4486 - val_root_mean_squared_error: 0.3650
# Epoch 20/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3606 - root_mean_squared_error: 0.2950 - val_loss: 0.4292 - val_root_mean_squared_error: 0.3277
# Epoch 21/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3956 - root_mean_squared_error: 0.2997 - val_loss: 0.4812 - val_root_mean_squared_error: 0.3460
# Epoch 22/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3710 - root_mean_squared_error: 0.2944 - val_loss: 0.5481 - val_root_mean_squared_error: 0.3774
# Epoch 23/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3760 - root_mean_squared_error: 0.2990 - val_loss: 0.5505 - val_root_mean_squared_error: 0.3654
# Epoch 24/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3666 - root_mean_squared_error: 0.2935 - val_loss: 0.5274 - val_root_mean_squared_error: 0.3684
# Epoch 25/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3571 - root_mean_squared_error: 0.2933 - val_loss: 0.4776 - val_root_mean_squared_error: 0.3342
# Epoch 26/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3594 - root_mean_squared_error: 0.2854 - val_loss: 0.5446 - val_root_mean_squared_error: 0.3499
# Epoch 27/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3406 - root_mean_squared_error: 0.2818 - val_loss: 0.4372 - val_root_mean_squared_error: 0.3296
# Epoch 28/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3620 - root_mean_squared_error: 0.2914 - val_loss: 0.5111 - val_root_mean_squared_error: 0.3565
# Epoch 29/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3605 - root_mean_squared_error: 0.2801 - val_loss: 0.5494 - val_root_mean_squared_error: 0.3684
# Epoch 30/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3639 - root_mean_squared_error: 0.2983 - val_loss: 0.5877 - val_root_mean_squared_error: 0.3696
# Epoch 31/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3337 - root_mean_squared_error: 0.2826 - val_loss: 0.5004 - val_root_mean_squared_error: 0.3379
# Epoch 32/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3413 - root_mean_squared_error: 0.2800 - val_loss: 0.4875 - val_root_mean_squared_error: 0.3464
# Epoch 33/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3255 - root_mean_squared_error: 0.2741 - val_loss: 0.5355 - val_root_mean_squared_error: 0.3526
# Epoch 34/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3526 - root_mean_squared_error: 0.2942 - val_loss: 0.4661 - val_root_mean_squared_error: 0.3428
# Epoch 35/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3340 - root_mean_squared_error: 0.2798 - val_loss: 0.7312 - val_root_mean_squared_error: 0.4027
# Epoch 36/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3405 - root_mean_squared_error: 0.2834 - val_loss: 0.5924 - val_root_mean_squared_error: 0.3811
# Epoch 37/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3447 - root_mean_squared_error: 0.2870 - val_loss: 0.5636 - val_root_mean_squared_error: 0.3650
# Epoch 38/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3340 - root_mean_squared_error: 0.2827 - val_loss: 0.4723 - val_root_mean_squared_error: 0.3464
# Epoch 39/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3277 - root_mean_squared_error: 0.2732 - val_loss: 0.4965 - val_root_mean_squared_error: 0.3351
# Epoch 40/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3420 - root_mean_squared_error: 0.2801 - val_loss: 0.4219 - val_root_mean_squared_error: 0.3225
# Epoch 41/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3332 - root_mean_squared_error: 0.2722 - val_loss: 0.4731 - val_root_mean_squared_error: 0.3291
# Epoch 42/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3196 - root_mean_squared_error: 0.2753 - val_loss: 0.5776 - val_root_mean_squared_error: 0.3675
# Epoch 43/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3260 - root_mean_squared_error: 0.2698 - val_loss: 0.4618 - val_root_mean_squared_error: 0.3234
# Epoch 44/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3252 - root_mean_squared_error: 0.2725 - val_loss: 0.5957 - val_root_mean_squared_error: 0.3692
# Epoch 45/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3323 - root_mean_squared_error: 0.2713 - val_loss: 0.6172 - val_root_mean_squared_error: 0.3766
# Epoch 46/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3189 - root_mean_squared_error: 0.2710 - val_loss: 0.6232 - val_root_mean_squared_error: 0.3815
# Epoch 47/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3185 - root_mean_squared_error: 0.2698 - val_loss: 0.7926 - val_root_mean_squared_error: 0.4129
# Epoch 48/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3168 - root_mean_squared_error: 0.2700 - val_loss: 0.5180 - val_root_mean_squared_error: 0.3599
# Epoch 49/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3112 - root_mean_squared_error: 0.2663 - val_loss: 0.5268 - val_root_mean_squared_error: 0.3374
# Epoch 50/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3290 - root_mean_squared_error: 0.2692 - val_loss: 0.5216 - val_root_mean_squared_error: 0.3437
# Epoch 51/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3188 - root_mean_squared_error: 0.2682 - val_loss: 0.6024 - val_root_mean_squared_error: 0.3633
# Epoch 52/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3189 - root_mean_squared_error: 0.2600 - val_loss: 0.5600 - val_root_mean_squared_error: 0.3625
# Epoch 53/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3182 - root_mean_squared_error: 0.2709 - val_loss: 0.6885 - val_root_mean_squared_error: 0.3750
# Epoch 54/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3127 - root_mean_squared_error: 0.2641 - val_loss: 0.6165 - val_root_mean_squared_error: 0.3552
# Epoch 55/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3017 - root_mean_squared_error: 0.2625 - val_loss: 0.5316 - val_root_mean_squared_error: 0.3249
# Epoch 56/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3161 - root_mean_squared_error: 0.2606 - val_loss: 0.6131 - val_root_mean_squared_error: 0.3717
# Epoch 57/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3083 - root_mean_squared_error: 0.2640 - val_loss: 0.6827 - val_root_mean_squared_error: 0.3839
# Epoch 58/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3126 - root_mean_squared_error: 0.2647 - val_loss: 0.5886 - val_root_mean_squared_error: 0.3374
# Epoch 59/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3192 - root_mean_squared_error: 0.2741 - val_loss: 0.6272 - val_root_mean_squared_error: 0.3415
# Epoch 60/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3131 - root_mean_squared_error: 0.2621 - val_loss: 0.5176 - val_root_mean_squared_error: 0.3455
# Epoch 61/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3110 - root_mean_squared_error: 0.2650 - val_loss: 0.5797 - val_root_mean_squared_error: 0.3642
# Epoch 62/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2980 - root_mean_squared_error: 0.2551 - val_loss: 0.6277 - val_root_mean_squared_error: 0.3658
# Epoch 63/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3101 - root_mean_squared_error: 0.2554 - val_loss: 0.5131 - val_root_mean_squared_error: 0.3277
# Epoch 64/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.3069 - root_mean_squared_error: 0.2644 - val_loss: 0.6461 - val_root_mean_squared_error: 0.3671
# Epoch 65/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2834 - root_mean_squared_error: 0.2550 - val_loss: 0.4980 - val_root_mean_squared_error: 0.3230
# Epoch 66/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3019 - root_mean_squared_error: 0.2554 - val_loss: 0.5826 - val_root_mean_squared_error: 0.3612
# Epoch 67/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2907 - root_mean_squared_error: 0.2542 - val_loss: 0.6513 - val_root_mean_squared_error: 0.3658
# Epoch 68/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3136 - root_mean_squared_error: 0.2596 - val_loss: 0.5304 - val_root_mean_squared_error: 0.3442
# Epoch 69/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.3076 - root_mean_squared_error: 0.2599 - val_loss: 0.6013 - val_root_mean_squared_error: 0.3586
# Epoch 70/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2941 - root_mean_squared_error: 0.2512 - val_loss: 0.5636 - val_root_mean_squared_error: 0.3530
# Epoch 71/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2660 - root_mean_squared_error: 0.2429 - val_loss: 0.5966 - val_root_mean_squared_error: 0.3556
# Epoch 72/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2941 - root_mean_squared_error: 0.2546 - val_loss: 0.7194 - val_root_mean_squared_error: 0.3835
# Epoch 73/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2972 - root_mean_squared_error: 0.2524 - val_loss: 0.6096 - val_root_mean_squared_error: 0.3586
# Epoch 74/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2943 - root_mean_squared_error: 0.2492 - val_loss: 0.5865 - val_root_mean_squared_error: 0.3401
# Epoch 75/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2987 - root_mean_squared_error: 0.2556 - val_loss: 0.5344 - val_root_mean_squared_error: 0.3508
# Epoch 76/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2984 - root_mean_squared_error: 0.2548 - val_loss: 0.4765 - val_root_mean_squared_error: 0.3319
# Epoch 77/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2833 - root_mean_squared_error: 0.2543 - val_loss: 0.4594 - val_root_mean_squared_error: 0.3023
# Epoch 78/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2930 - root_mean_squared_error: 0.2580 - val_loss: 0.5295 - val_root_mean_squared_error: 0.3291
# Epoch 79/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2923 - root_mean_squared_error: 0.2577 - val_loss: 0.5932 - val_root_mean_squared_error: 0.3446
# Epoch 80/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2908 - root_mean_squared_error: 0.2478 - val_loss: 0.5093 - val_root_mean_squared_error: 0.3406
# Epoch 81/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2929 - root_mean_squared_error: 0.2599 - val_loss: 0.4858 - val_root_mean_squared_error: 0.3305
# Epoch 82/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2884 - root_mean_squared_error: 0.2527 - val_loss: 0.5638 - val_root_mean_squared_error: 0.3508
# Epoch 83/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2893 - root_mean_squared_error: 0.2528 - val_loss: 0.6951 - val_root_mean_squared_error: 0.3738
# Epoch 84/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2864 - root_mean_squared_error: 0.2512 - val_loss: 0.5715 - val_root_mean_squared_error: 0.3351
# Epoch 85/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2724 - root_mean_squared_error: 0.2394 - val_loss: 0.5610 - val_root_mean_squared_error: 0.3360
# Epoch 86/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2884 - root_mean_squared_error: 0.2502 - val_loss: 0.6284 - val_root_mean_squared_error: 0.3625
# Epoch 87/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2938 - root_mean_squared_error: 0.2622 - val_loss: 0.5644 - val_root_mean_squared_error: 0.3333
# Epoch 88/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2954 - root_mean_squared_error: 0.2536 - val_loss: 0.5012 - val_root_mean_squared_error: 0.3410
# Epoch 89/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2877 - root_mean_squared_error: 0.2482 - val_loss: 0.5802 - val_root_mean_squared_error: 0.3360
# Epoch 90/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2837 - root_mean_squared_error: 0.2453 - val_loss: 0.7122 - val_root_mean_squared_error: 0.3688
# Epoch 91/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2896 - root_mean_squared_error: 0.2582 - val_loss: 0.6121 - val_root_mean_squared_error: 0.3486
# Epoch 92/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2888 - root_mean_squared_error: 0.2499 - val_loss: 0.6221 - val_root_mean_squared_error: 0.3300
# Epoch 93/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2958 - root_mean_squared_error: 0.2504 - val_loss: 0.6273 - val_root_mean_squared_error: 0.3612
# Epoch 94/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2842 - root_mean_squared_error: 0.2501 - val_loss: 0.6334 - val_root_mean_squared_error: 0.3517
# Epoch 95/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2804 - root_mean_squared_error: 0.2474 - val_loss: 0.7547 - val_root_mean_squared_error: 0.3946
# Epoch 96/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2843 - root_mean_squared_error: 0.2423 - val_loss: 0.5304 - val_root_mean_squared_error: 0.3272
# Epoch 97/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2813 - root_mean_squared_error: 0.2437 - val_loss: 0.5501 - val_root_mean_squared_error: 0.3370
# Epoch 98/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2886 - root_mean_squared_error: 0.2443 - val_loss: 0.6478 - val_root_mean_squared_error: 0.3513
# Epoch 99/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2782 - root_mean_squared_error: 0.2460 - val_loss: 0.5241 - val_root_mean_squared_error: 0.3305
# Epoch 100/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2830 - root_mean_squared_error: 0.2501 - val_loss: 0.6374 - val_root_mean_squared_error: 0.3446
# Epoch 101/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2765 - root_mean_squared_error: 0.2478 - val_loss: 0.6533 - val_root_mean_squared_error: 0.3750
# Epoch 102/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2568 - root_mean_squared_error: 0.2362 - val_loss: 0.5413 - val_root_mean_squared_error: 0.3296
# Epoch 103/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2711 - root_mean_squared_error: 0.2427 - val_loss: 0.5472 - val_root_mean_squared_error: 0.3310
# Epoch 104/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2801 - root_mean_squared_error: 0.2394 - val_loss: 0.6424 - val_root_mean_squared_error: 0.3517
# Epoch 105/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2897 - root_mean_squared_error: 0.2471 - val_loss: 0.5704 - val_root_mean_squared_error: 0.3517
# Epoch 106/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2583 - root_mean_squared_error: 0.2378 - val_loss: 0.6644 - val_root_mean_squared_error: 0.3513
# Epoch 107/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2751 - root_mean_squared_error: 0.2370 - val_loss: 0.6945 - val_root_mean_squared_error: 0.3513
# Epoch 108/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2636 - root_mean_squared_error: 0.2355 - val_loss: 0.6713 - val_root_mean_squared_error: 0.3774
# Epoch 109/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2596 - root_mean_squared_error: 0.2358 - val_loss: 0.6144 - val_root_mean_squared_error: 0.3442
# Epoch 110/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2575 - root_mean_squared_error: 0.2366 - val_loss: 0.5903 - val_root_mean_squared_error: 0.3383
# Epoch 111/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2617 - root_mean_squared_error: 0.2258 - val_loss: 0.7622 - val_root_mean_squared_error: 0.3473
# Epoch 112/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2724 - root_mean_squared_error: 0.2384 - val_loss: 0.5530 - val_root_mean_squared_error: 0.3215
# Epoch 113/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2548 - root_mean_squared_error: 0.2337 - val_loss: 0.6743 - val_root_mean_squared_error: 0.3696
# Epoch 114/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2539 - root_mean_squared_error: 0.2272 - val_loss: 0.6908 - val_root_mean_squared_error: 0.3491
# Epoch 115/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2726 - root_mean_squared_error: 0.2413 - val_loss: 0.6838 - val_root_mean_squared_error: 0.3491
# Epoch 116/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2574 - root_mean_squared_error: 0.2238 - val_loss: 0.6647 - val_root_mean_squared_error: 0.3455
# Epoch 117/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2568 - root_mean_squared_error: 0.2309 - val_loss: 0.5850 - val_root_mean_squared_error: 0.3277
# Epoch 118/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2483 - root_mean_squared_error: 0.2277 - val_loss: 0.6748 - val_root_mean_squared_error: 0.3234
# Epoch 119/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2375 - root_mean_squared_error: 0.2179 - val_loss: 0.4637 - val_root_mean_squared_error: 0.2834
# Epoch 120/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2428 - root_mean_squared_error: 0.2148 - val_loss: 0.6104 - val_root_mean_squared_error: 0.3177
# Epoch 121/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2500 - root_mean_squared_error: 0.2221 - val_loss: 0.7627 - val_root_mean_squared_error: 0.3625
# Epoch 122/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2673 - root_mean_squared_error: 0.2301 - val_loss: 0.4655 - val_root_mean_squared_error: 0.2940
# Epoch 123/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2463 - root_mean_squared_error: 0.2221 - val_loss: 0.6270 - val_root_mean_squared_error: 0.3342
# Epoch 124/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2523 - root_mean_squared_error: 0.2231 - val_loss: 0.5410 - val_root_mean_squared_error: 0.3172
# Epoch 125/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2452 - root_mean_squared_error: 0.2238 - val_loss: 0.6046 - val_root_mean_squared_error: 0.3113
# Epoch 126/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2312 - root_mean_squared_error: 0.2164 - val_loss: 0.6395 - val_root_mean_squared_error: 0.3442
# Epoch 127/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2305 - root_mean_squared_error: 0.2075 - val_loss: 0.7902 - val_root_mean_squared_error: 0.3582
# Epoch 128/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2500 - root_mean_squared_error: 0.2157 - val_loss: 0.6274 - val_root_mean_squared_error: 0.3406
# Epoch 129/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2468 - root_mean_squared_error: 0.2193 - val_loss: 0.6628 - val_root_mean_squared_error: 0.3337
# Epoch 130/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2348 - root_mean_squared_error: 0.2157 - val_loss: 0.6369 - val_root_mean_squared_error: 0.3249
# Epoch 131/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2558 - root_mean_squared_error: 0.2289 - val_loss: 0.6296 - val_root_mean_squared_error: 0.3556
# Epoch 132/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2291 - root_mean_squared_error: 0.2175 - val_loss: 0.6511 - val_root_mean_squared_error: 0.3337
# Epoch 133/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2283 - root_mean_squared_error: 0.2201 - val_loss: 0.5962 - val_root_mean_squared_error: 0.3277
# Epoch 134/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2378 - root_mean_squared_error: 0.2189 - val_loss: 0.5590 - val_root_mean_squared_error: 0.3043
# Epoch 135/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2362 - root_mean_squared_error: 0.2198 - val_loss: 0.5358 - val_root_mean_squared_error: 0.3133
# Epoch 136/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2205 - root_mean_squared_error: 0.2079 - val_loss: 0.5555 - val_root_mean_squared_error: 0.2966
# Epoch 137/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2375 - root_mean_squared_error: 0.2164 - val_loss: 0.6265 - val_root_mean_squared_error: 0.3388
# Epoch 138/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2367 - root_mean_squared_error: 0.2179 - val_loss: 0.6093 - val_root_mean_squared_error: 0.3314
# Epoch 139/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2241 - root_mean_squared_error: 0.2120 - val_loss: 0.9250 - val_root_mean_squared_error: 0.3750
# Epoch 140/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2312 - root_mean_squared_error: 0.2077 - val_loss: 0.8359 - val_root_mean_squared_error: 0.3633
# Epoch 141/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2205 - root_mean_squared_error: 0.2034 - val_loss: 0.7506 - val_root_mean_squared_error: 0.3300
# Epoch 142/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2397 - root_mean_squared_error: 0.2191 - val_loss: 0.8530 - val_root_mean_squared_error: 0.3895
# Epoch 143/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2254 - root_mean_squared_error: 0.2110 - val_loss: 0.5546 - val_root_mean_squared_error: 0.3028
# Epoch 144/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2383 - root_mean_squared_error: 0.2125 - val_loss: 0.8625 - val_root_mean_squared_error: 0.3946
# Epoch 145/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2438 - root_mean_squared_error: 0.2163 - val_loss: 0.7456 - val_root_mean_squared_error: 0.3446
# Epoch 146/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2342 - root_mean_squared_error: 0.2171 - val_loss: 0.6304 - val_root_mean_squared_error: 0.3206
# Epoch 147/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2223 - root_mean_squared_error: 0.2092 - val_loss: 0.7255 - val_root_mean_squared_error: 0.3491
# Epoch 148/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2207 - root_mean_squared_error: 0.2029 - val_loss: 0.6262 - val_root_mean_squared_error: 0.3379
# Epoch 149/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2338 - root_mean_squared_error: 0.2145 - val_loss: 0.6348 - val_root_mean_squared_error: 0.3244
# Epoch 150/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2125 - root_mean_squared_error: 0.2046 - val_loss: 0.5692 - val_root_mean_squared_error: 0.2992
# Epoch 151/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2416 - root_mean_squared_error: 0.2112 - val_loss: 0.7840 - val_root_mean_squared_error: 0.3778
# Epoch 152/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2268 - root_mean_squared_error: 0.2055 - val_loss: 0.7537 - val_root_mean_squared_error: 0.3729
# Epoch 153/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2265 - root_mean_squared_error: 0.2085 - val_loss: 0.7409 - val_root_mean_squared_error: 0.3582
# Epoch 154/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2199 - root_mean_squared_error: 0.2079 - val_loss: 0.7073 - val_root_mean_squared_error: 0.3230
# Epoch 155/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2162 - root_mean_squared_error: 0.2044 - val_loss: 0.6845 - val_root_mean_squared_error: 0.3410
# Epoch 156/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2271 - root_mean_squared_error: 0.2062 - val_loss: 0.7900 - val_root_mean_squared_error: 0.3526
# Epoch 157/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2042 - root_mean_squared_error: 0.2012 - val_loss: 0.8798 - val_root_mean_squared_error: 0.3620
# Epoch 158/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2265 - root_mean_squared_error: 0.2087 - val_loss: 0.7709 - val_root_mean_squared_error: 0.3437
# Epoch 159/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2159 - root_mean_squared_error: 0.1988 - val_loss: 0.8720 - val_root_mean_squared_error: 0.3717
# Epoch 160/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2344 - root_mean_squared_error: 0.2134 - val_loss: 0.8023 - val_root_mean_squared_error: 0.3742
# Epoch 161/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2159 - root_mean_squared_error: 0.1951 - val_loss: 0.5947 - val_root_mean_squared_error: 0.3157
# Epoch 162/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2374 - root_mean_squared_error: 0.2132 - val_loss: 0.7403 - val_root_mean_squared_error: 0.3671
# Epoch 163/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2215 - root_mean_squared_error: 0.2044 - val_loss: 0.9342 - val_root_mean_squared_error: 0.3729
# Epoch 164/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2305 - root_mean_squared_error: 0.2121 - val_loss: 0.5724 - val_root_mean_squared_error: 0.3220
# Epoch 165/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2163 - root_mean_squared_error: 0.2062 - val_loss: 0.8742 - val_root_mean_squared_error: 0.3907
# Epoch 166/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2090 - root_mean_squared_error: 0.2021 - val_loss: 0.7071 - val_root_mean_squared_error: 0.3410
# Epoch 167/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.1952 - root_mean_squared_error: 0.1928 - val_loss: 0.5644 - val_root_mean_squared_error: 0.2909
# Epoch 168/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2270 - root_mean_squared_error: 0.1985 - val_loss: 0.5014 - val_root_mean_squared_error: 0.3206
# Epoch 169/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2133 - root_mean_squared_error: 0.2019 - val_loss: 0.7379 - val_root_mean_squared_error: 0.3455
# Epoch 170/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2069 - root_mean_squared_error: 0.1926 - val_loss: 0.6992 - val_root_mean_squared_error: 0.3508
# Epoch 171/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2208 - root_mean_squared_error: 0.2083 - val_loss: 0.7396 - val_root_mean_squared_error: 0.3543
# Epoch 172/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2243 - root_mean_squared_error: 0.2116 - val_loss: 0.7077 - val_root_mean_squared_error: 0.3286
# Epoch 173/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2068 - root_mean_squared_error: 0.2004 - val_loss: 0.8558 - val_root_mean_squared_error: 0.3491
# Epoch 174/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2018 - root_mean_squared_error: 0.1963 - val_loss: 0.6735 - val_root_mean_squared_error: 0.3446
# Epoch 175/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2105 - root_mean_squared_error: 0.1928 - val_loss: 0.7043 - val_root_mean_squared_error: 0.3234
# Epoch 176/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2356 - root_mean_squared_error: 0.2072 - val_loss: 0.7395 - val_root_mean_squared_error: 0.3419
# Epoch 177/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2010 - root_mean_squared_error: 0.1975 - val_loss: 0.6688 - val_root_mean_squared_error: 0.3513
# Epoch 178/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2102 - root_mean_squared_error: 0.1973 - val_loss: 0.7425 - val_root_mean_squared_error: 0.3495
# Epoch 179/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2254 - root_mean_squared_error: 0.2006 - val_loss: 0.8054 - val_root_mean_squared_error: 0.3499
# Epoch 180/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2087 - root_mean_squared_error: 0.2006 - val_loss: 0.6047 - val_root_mean_squared_error: 0.3337
# Epoch 181/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2317 - root_mean_squared_error: 0.1985 - val_loss: 0.7586 - val_root_mean_squared_error: 0.3504
# Epoch 182/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2091 - root_mean_squared_error: 0.1959 - val_loss: 0.8265 - val_root_mean_squared_error: 0.3569
# Epoch 183/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2048 - root_mean_squared_error: 0.1985 - val_loss: 0.7130 - val_root_mean_squared_error: 0.3486
# Epoch 184/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2345 - root_mean_squared_error: 0.2127 - val_loss: 0.5954 - val_root_mean_squared_error: 0.3342
# Epoch 185/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2188 - root_mean_squared_error: 0.2038 - val_loss: 0.5948 - val_root_mean_squared_error: 0.3098
# Epoch 186/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2058 - root_mean_squared_error: 0.2010 - val_loss: 0.5265 - val_root_mean_squared_error: 0.3073
# Epoch 187/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2073 - root_mean_squared_error: 0.2057 - val_loss: 0.6688 - val_root_mean_squared_error: 0.3446
# Epoch 188/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2071 - root_mean_squared_error: 0.2031 - val_loss: 0.7104 - val_root_mean_squared_error: 0.3215
# Epoch 189/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2082 - root_mean_squared_error: 0.1924 - val_loss: 0.6737 - val_root_mean_squared_error: 0.3191
# Epoch 190/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2087 - root_mean_squared_error: 0.1953 - val_loss: 0.5133 - val_root_mean_squared_error: 0.2898
# Epoch 191/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1955 - root_mean_squared_error: 0.1961 - val_loss: 0.6912 - val_root_mean_squared_error: 0.3552
# Epoch 192/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.2041 - root_mean_squared_error: 0.1854 - val_loss: 0.6251 - val_root_mean_squared_error: 0.3220
# Epoch 193/200
# 102/102 [==============================] - 1s 7ms/step - loss: 0.1953 - root_mean_squared_error: 0.1883 - val_loss: 0.6372 - val_root_mean_squared_error: 0.3083
# Epoch 194/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.1997 - root_mean_squared_error: 0.1854 - val_loss: 0.6171 - val_root_mean_squared_error: 0.3167
# Epoch 195/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.2004 - root_mean_squared_error: 0.1825 - val_loss: 0.6781 - val_root_mean_squared_error: 0.3093
# Epoch 196/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.1922 - root_mean_squared_error: 0.1867 - val_loss: 0.7019 - val_root_mean_squared_error: 0.3499
# Epoch 197/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.1976 - root_mean_squared_error: 0.1812 - val_loss: 0.6102 - val_root_mean_squared_error: 0.3239
# Epoch 198/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.1876 - root_mean_squared_error: 0.1808 - val_loss: 0.9237 - val_root_mean_squared_error: 0.3733
# Epoch 199/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.1870 - root_mean_squared_error: 0.1848 - val_loss: 0.8942 - val_root_mean_squared_error: 0.3612
# Epoch 200/200
# 102/102 [==============================] - 1s 6ms/step - loss: 0.1881 - root_mean_squared_error: 0.1787 - val_loss: 0.6299 - val_root_mean_squared_error: 0.3068
# Epoch 1/200
# 51/51 [==============================] - 3s 20ms/step - loss: 1.3927 - root_mean_squared_error: 0.6997 - val_loss: 1.5840 - val_root_mean_squared_error: 0.7222
# Epoch 2/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3773 - root_mean_squared_error: 0.7017 - val_loss: 1.4505 - val_root_mean_squared_error: 0.7271
# Epoch 3/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3737 - root_mean_squared_error: 0.7038 - val_loss: 1.4774 - val_root_mean_squared_error: 0.7155
# Epoch 4/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3670 - root_mean_squared_error: 0.6955 - val_loss: 1.4599 - val_root_mean_squared_error: 0.7228
# Epoch 5/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.3347 - root_mean_squared_error: 0.6886 - val_loss: 1.3736 - val_root_mean_squared_error: 0.7023
# Epoch 6/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.2832 - root_mean_squared_error: 0.6787 - val_loss: 1.2881 - val_root_mean_squared_error: 0.6760
# Epoch 7/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.1830 - root_mean_squared_error: 0.6559 - val_loss: 1.1308 - val_root_mean_squared_error: 0.6509
# Epoch 8/200
# 51/51 [==============================] - 0s 7ms/step - loss: 1.0392 - root_mean_squared_error: 0.6220 - val_loss: 1.0415 - val_root_mean_squared_error: 0.6129
# Epoch 9/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.8675 - root_mean_squared_error: 0.5656 - val_loss: 0.8013 - val_root_mean_squared_error: 0.5384
# Epoch 10/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.7491 - root_mean_squared_error: 0.5199 - val_loss: 0.5903 - val_root_mean_squared_error: 0.4781
# Epoch 11/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.6400 - root_mean_squared_error: 0.4650 - val_loss: 0.5729 - val_root_mean_squared_error: 0.4476
# Epoch 12/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.5829 - root_mean_squared_error: 0.4334 - val_loss: 0.4880 - val_root_mean_squared_error: 0.3871
# Epoch 13/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.5317 - root_mean_squared_error: 0.4027 - val_loss: 0.5297 - val_root_mean_squared_error: 0.4184
# Epoch 14/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.5053 - root_mean_squared_error: 0.3901 - val_loss: 0.3139 - val_root_mean_squared_error: 0.3360
# Epoch 15/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.4672 - root_mean_squared_error: 0.3599 - val_loss: 0.3804 - val_root_mean_squared_error: 0.3491
# Epoch 16/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.4849 - root_mean_squared_error: 0.3580 - val_loss: 0.3802 - val_root_mean_squared_error: 0.3182
# Epoch 17/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.4501 - root_mean_squared_error: 0.3457 - val_loss: 0.5715 - val_root_mean_squared_error: 0.3957
# Epoch 18/200
# 51/51 [==============================] - 0s 10ms/step - loss: 0.4197 - root_mean_squared_error: 0.3313 - val_loss: 0.2778 - val_root_mean_squared_error: 0.3053
# Epoch 19/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.4429 - root_mean_squared_error: 0.3350 - val_loss: 0.3376 - val_root_mean_squared_error: 0.3286
# Epoch 20/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.4319 - root_mean_squared_error: 0.3319 - val_loss: 0.4688 - val_root_mean_squared_error: 0.3646
# Epoch 21/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.4094 - root_mean_squared_error: 0.3153 - val_loss: 0.3631 - val_root_mean_squared_error: 0.3225
# Epoch 22/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.4109 - root_mean_squared_error: 0.3263 - val_loss: 0.3767 - val_root_mean_squared_error: 0.3365
# Epoch 23/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.4025 - root_mean_squared_error: 0.3200 - val_loss: 0.3155 - val_root_mean_squared_error: 0.2951
# Epoch 24/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.4005 - root_mean_squared_error: 0.3189 - val_loss: 0.3782 - val_root_mean_squared_error: 0.3253
# Epoch 25/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3886 - root_mean_squared_error: 0.3067 - val_loss: 0.4236 - val_root_mean_squared_error: 0.3388
# Epoch 26/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3882 - root_mean_squared_error: 0.3047 - val_loss: 0.4293 - val_root_mean_squared_error: 0.3742
# Epoch 27/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3751 - root_mean_squared_error: 0.3066 - val_loss: 0.4844 - val_root_mean_squared_error: 0.3642
# Epoch 28/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3674 - root_mean_squared_error: 0.2964 - val_loss: 0.4983 - val_root_mean_squared_error: 0.3410
# Epoch 29/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3512 - root_mean_squared_error: 0.2933 - val_loss: 0.4433 - val_root_mean_squared_error: 0.3370
# Epoch 30/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3662 - root_mean_squared_error: 0.2939 - val_loss: 0.4183 - val_root_mean_squared_error: 0.3356
# Epoch 31/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3688 - root_mean_squared_error: 0.3022 - val_loss: 0.2860 - val_root_mean_squared_error: 0.2779
# Epoch 32/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3597 - root_mean_squared_error: 0.3034 - val_loss: 0.3195 - val_root_mean_squared_error: 0.2866
# Epoch 33/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3521 - root_mean_squared_error: 0.2898 - val_loss: 0.3252 - val_root_mean_squared_error: 0.2909
# Epoch 34/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3508 - root_mean_squared_error: 0.2839 - val_loss: 0.4082 - val_root_mean_squared_error: 0.3305
# Epoch 35/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3643 - root_mean_squared_error: 0.2900 - val_loss: 0.3488 - val_root_mean_squared_error: 0.2877
# Epoch 36/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3535 - root_mean_squared_error: 0.2851 - val_loss: 0.4906 - val_root_mean_squared_error: 0.3314
# Epoch 37/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3384 - root_mean_squared_error: 0.2854 - val_loss: 0.3279 - val_root_mean_squared_error: 0.2951
# Epoch 38/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3543 - root_mean_squared_error: 0.2931 - val_loss: 0.4373 - val_root_mean_squared_error: 0.3328
# Epoch 39/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3389 - root_mean_squared_error: 0.2846 - val_loss: 0.5967 - val_root_mean_squared_error: 0.3709
# Epoch 40/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3574 - root_mean_squared_error: 0.2910 - val_loss: 0.3894 - val_root_mean_squared_error: 0.3053
# Epoch 41/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3435 - root_mean_squared_error: 0.2842 - val_loss: 0.4148 - val_root_mean_squared_error: 0.3063
# Epoch 42/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3265 - root_mean_squared_error: 0.2761 - val_loss: 0.3910 - val_root_mean_squared_error: 0.3157
# Epoch 43/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3320 - root_mean_squared_error: 0.2809 - val_loss: 0.4588 - val_root_mean_squared_error: 0.3455
# Epoch 44/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3218 - root_mean_squared_error: 0.2660 - val_loss: 0.5433 - val_root_mean_squared_error: 0.3591
# Epoch 45/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3432 - root_mean_squared_error: 0.2857 - val_loss: 0.4230 - val_root_mean_squared_error: 0.3328
# Epoch 46/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3282 - root_mean_squared_error: 0.2793 - val_loss: 0.4574 - val_root_mean_squared_error: 0.3543
# Epoch 47/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3168 - root_mean_squared_error: 0.2791 - val_loss: 0.4731 - val_root_mean_squared_error: 0.3401
# Epoch 48/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3193 - root_mean_squared_error: 0.2700 - val_loss: 0.4324 - val_root_mean_squared_error: 0.3286
# Epoch 49/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3266 - root_mean_squared_error: 0.2737 - val_loss: 0.4070 - val_root_mean_squared_error: 0.3277
# Epoch 50/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3405 - root_mean_squared_error: 0.2754 - val_loss: 0.4708 - val_root_mean_squared_error: 0.3305
# Epoch 51/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3264 - root_mean_squared_error: 0.2765 - val_loss: 0.3861 - val_root_mean_squared_error: 0.3023
# Epoch 52/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3307 - root_mean_squared_error: 0.2716 - val_loss: 0.3657 - val_root_mean_squared_error: 0.3043
# Epoch 53/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3290 - root_mean_squared_error: 0.2797 - val_loss: 0.4005 - val_root_mean_squared_error: 0.3157
# Epoch 54/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3139 - root_mean_squared_error: 0.2730 - val_loss: 0.4212 - val_root_mean_squared_error: 0.3058
# Epoch 55/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2940 - root_mean_squared_error: 0.2611 - val_loss: 0.4845 - val_root_mean_squared_error: 0.3310
# Epoch 56/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3090 - root_mean_squared_error: 0.2587 - val_loss: 0.3661 - val_root_mean_squared_error: 0.2925
# Epoch 57/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3135 - root_mean_squared_error: 0.2688 - val_loss: 0.4236 - val_root_mean_squared_error: 0.3177
# Epoch 58/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3249 - root_mean_squared_error: 0.2755 - val_loss: 0.4738 - val_root_mean_squared_error: 0.3328
# Epoch 59/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3233 - root_mean_squared_error: 0.2780 - val_loss: 0.4141 - val_root_mean_squared_error: 0.3083
# Epoch 60/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3203 - root_mean_squared_error: 0.2741 - val_loss: 0.5341 - val_root_mean_squared_error: 0.3442
# Epoch 61/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3086 - root_mean_squared_error: 0.2715 - val_loss: 0.5065 - val_root_mean_squared_error: 0.3460
# Epoch 62/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3068 - root_mean_squared_error: 0.2675 - val_loss: 0.5630 - val_root_mean_squared_error: 0.3526
# Epoch 63/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3096 - root_mean_squared_error: 0.2628 - val_loss: 0.5622 - val_root_mean_squared_error: 0.3654
# Epoch 64/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2781 - root_mean_squared_error: 0.2588 - val_loss: 0.3926 - val_root_mean_squared_error: 0.2839
# Epoch 65/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3003 - root_mean_squared_error: 0.2630 - val_loss: 0.4604 - val_root_mean_squared_error: 0.3220
# Epoch 66/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3098 - root_mean_squared_error: 0.2672 - val_loss: 0.5157 - val_root_mean_squared_error: 0.3388
# Epoch 67/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3117 - root_mean_squared_error: 0.2625 - val_loss: 0.4986 - val_root_mean_squared_error: 0.3397
# Epoch 68/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2912 - root_mean_squared_error: 0.2600 - val_loss: 0.3703 - val_root_mean_squared_error: 0.2972
# Epoch 69/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3072 - root_mean_squared_error: 0.2662 - val_loss: 0.4805 - val_root_mean_squared_error: 0.3215
# Epoch 70/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2910 - root_mean_squared_error: 0.2566 - val_loss: 0.4696 - val_root_mean_squared_error: 0.3187
# Epoch 71/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2913 - root_mean_squared_error: 0.2631 - val_loss: 0.4767 - val_root_mean_squared_error: 0.3410
# Epoch 72/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.3140 - root_mean_squared_error: 0.2630 - val_loss: 0.5069 - val_root_mean_squared_error: 0.3526
# Epoch 73/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2998 - root_mean_squared_error: 0.2565 - val_loss: 0.4259 - val_root_mean_squared_error: 0.3123
# Epoch 74/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2804 - root_mean_squared_error: 0.2531 - val_loss: 0.4686 - val_root_mean_squared_error: 0.3182
# Epoch 75/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2933 - root_mean_squared_error: 0.2551 - val_loss: 0.4476 - val_root_mean_squared_error: 0.3272
# Epoch 76/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.2966 - root_mean_squared_error: 0.2597 - val_loss: 0.6778 - val_root_mean_squared_error: 0.3778
# Epoch 77/200
# ...
# 13/13 [==============================] - 0s 10ms/step - loss: 0.4161 - root_mean_squared_error: 0.3288 - val_loss: 0.2608 - val_root_mean_squared_error: 0.2462
# Epoch 110/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3776 - root_mean_squared_error: 0.3039 - val_loss: 0.3312 - val_root_mean_squared_error: 0.2966
# Epoch 111/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3591 - root_mean_squared_error: 0.2896 - val_loss: 0.5533 - val_root_mean_squared_error: 0.3451
# Epoch 112/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3708 - root_mean_squared_error: 0.2888 - val_loss: 0.4589 - val_root_mean_squared_error: 0.3451
# Epoch 113/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.4003 - root_mean_squared_error: 0.3144 - val_loss: 0.3804 - val_root_mean_squared_error: 0.3153
# Epoch 114/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3622 - root_mean_squared_error: 0.2961 - val_loss: 0.3289 - val_root_mean_squared_error: 0.3108
# Epoch 115/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.3581 - root_mean_squared_error: 0.2888 - val_loss: 0.4137 - val_root_mean_squared_error: 0.3211
# Epoch 116/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3660 - root_mean_squared_error: 0.3015 - val_loss: 0.2813 - val_root_mean_squared_error: 0.2437
# Epoch 117/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3617 - root_mean_squared_error: 0.2934 - val_loss: 0.4935 - val_root_mean_squared_error: 0.3365
# Epoch 118/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3472 - root_mean_squared_error: 0.2894 - val_loss: 0.5102 - val_root_mean_squared_error: 0.3608
# Epoch 119/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3837 - root_mean_squared_error: 0.2994 - val_loss: 0.6203 - val_root_mean_squared_error: 0.4385
# Epoch 120/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3724 - root_mean_squared_error: 0.3053 - val_loss: 0.3562 - val_root_mean_squared_error: 0.3211
# Epoch 121/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3767 - root_mean_squared_error: 0.2915 - val_loss: 0.3188 - val_root_mean_squared_error: 0.3028
# Epoch 122/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3640 - root_mean_squared_error: 0.2870 - val_loss: 0.4960 - val_root_mean_squared_error: 0.3314
# Epoch 123/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3790 - root_mean_squared_error: 0.3081 - val_loss: 0.3212 - val_root_mean_squared_error: 0.3123
# Epoch 124/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3978 - root_mean_squared_error: 0.3101 - val_loss: 0.2389 - val_root_mean_squared_error: 0.2274
# Epoch 125/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3778 - root_mean_squared_error: 0.3027 - val_loss: 0.3712 - val_root_mean_squared_error: 0.3143
# Epoch 126/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3907 - root_mean_squared_error: 0.3102 - val_loss: 0.2476 - val_root_mean_squared_error: 0.2191
# Epoch 127/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3592 - root_mean_squared_error: 0.2760 - val_loss: 0.2807 - val_root_mean_squared_error: 0.2560
# Epoch 128/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3688 - root_mean_squared_error: 0.2797 - val_loss: 0.2876 - val_root_mean_squared_error: 0.2437
# Epoch 129/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3822 - root_mean_squared_error: 0.2999 - val_loss: 0.2089 - val_root_mean_squared_error: 0.2379
# Epoch 130/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3822 - root_mean_squared_error: 0.2939 - val_loss: 0.3515 - val_root_mean_squared_error: 0.2818
# Epoch 131/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3518 - root_mean_squared_error: 0.2865 - val_loss: 0.5050 - val_root_mean_squared_error: 0.3324
# Epoch 132/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3765 - root_mean_squared_error: 0.2889 - val_loss: 0.4444 - val_root_mean_squared_error: 0.3253
# Epoch 133/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3797 - root_mean_squared_error: 0.2944 - val_loss: 0.2877 - val_root_mean_squared_error: 0.2596
# Epoch 134/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.3528 - root_mean_squared_error: 0.2905 - val_loss: 0.6889 - val_root_mean_squared_error: 0.4169
# Epoch 135/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.4047 - root_mean_squared_error: 0.2985 - val_loss: 0.4986 - val_root_mean_squared_error: 0.3244
# Epoch 136/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3660 - root_mean_squared_error: 0.2917 - val_loss: 0.4940 - val_root_mean_squared_error: 0.3725
# Epoch 137/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3947 - root_mean_squared_error: 0.3022 - val_loss: 0.5033 - val_root_mean_squared_error: 0.3778
# Epoch 138/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3968 - root_mean_squared_error: 0.3073 - val_loss: 0.7053 - val_root_mean_squared_error: 0.4710
# Epoch 139/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3515 - root_mean_squared_error: 0.2774 - val_loss: 0.3507 - val_root_mean_squared_error: 0.2654
# Epoch 140/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3655 - root_mean_squared_error: 0.2976 - val_loss: 0.3940 - val_root_mean_squared_error: 0.3314
# Epoch 141/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3768 - root_mean_squared_error: 0.2851 - val_loss: 0.3251 - val_root_mean_squared_error: 0.2683
# Epoch 142/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3908 - root_mean_squared_error: 0.3028 - val_loss: 0.4115 - val_root_mean_squared_error: 0.3211
# Epoch 143/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3615 - root_mean_squared_error: 0.2939 - val_loss: 0.4766 - val_root_mean_squared_error: 0.3629
# Epoch 144/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3538 - root_mean_squared_error: 0.2912 - val_loss: 0.3526 - val_root_mean_squared_error: 0.3083
# Epoch 145/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3392 - root_mean_squared_error: 0.2767 - val_loss: 0.3335 - val_root_mean_squared_error: 0.3013
# Epoch 146/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3608 - root_mean_squared_error: 0.2914 - val_loss: 0.4870 - val_root_mean_squared_error: 0.3530
# Epoch 147/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3608 - root_mean_squared_error: 0.3067 - val_loss: 0.6661 - val_root_mean_squared_error: 0.4210
# Epoch 148/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3584 - root_mean_squared_error: 0.2908 - val_loss: 0.3631 - val_root_mean_squared_error: 0.2909
# Epoch 149/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.3613 - root_mean_squared_error: 0.2845 - val_loss: 0.3283 - val_root_mean_squared_error: 0.2893
# Epoch 150/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3563 - root_mean_squared_error: 0.2913 - val_loss: 0.5347 - val_root_mean_squared_error: 0.3827
# Epoch 151/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3587 - root_mean_squared_error: 0.2952 - val_loss: 0.3267 - val_root_mean_squared_error: 0.2643
# Epoch 152/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3542 - root_mean_squared_error: 0.2807 - val_loss: 0.7347 - val_root_mean_squared_error: 0.3791
# Epoch 153/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3896 - root_mean_squared_error: 0.2874 - val_loss: 0.2808 - val_root_mean_squared_error: 0.2327
# Epoch 154/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3468 - root_mean_squared_error: 0.2865 - val_loss: 0.7373 - val_root_mean_squared_error: 0.4272
# Epoch 155/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3277 - root_mean_squared_error: 0.2868 - val_loss: 0.4579 - val_root_mean_squared_error: 0.3253
# Epoch 156/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3523 - root_mean_squared_error: 0.2922 - val_loss: 0.5027 - val_root_mean_squared_error: 0.3725
# Epoch 157/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3832 - root_mean_squared_error: 0.2837 - val_loss: 0.4551 - val_root_mean_squared_error: 0.3608
# Epoch 158/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3472 - root_mean_squared_error: 0.2801 - val_loss: 0.4174 - val_root_mean_squared_error: 0.3517
# Epoch 159/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3516 - root_mean_squared_error: 0.2720 - val_loss: 0.3202 - val_root_mean_squared_error: 0.2850
# Epoch 160/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3335 - root_mean_squared_error: 0.2824 - val_loss: 0.4014 - val_root_mean_squared_error: 0.3300
# Epoch 161/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3603 - root_mean_squared_error: 0.2890 - val_loss: 0.4635 - val_root_mean_squared_error: 0.3401
# Epoch 162/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.3469 - root_mean_squared_error: 0.2834 - val_loss: 0.5916 - val_root_mean_squared_error: 0.3981
# Epoch 163/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3614 - root_mean_squared_error: 0.2876 - val_loss: 0.4119 - val_root_mean_squared_error: 0.3258
# Epoch 164/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3519 - root_mean_squared_error: 0.2839 - val_loss: 0.3703 - val_root_mean_squared_error: 0.2977
# Epoch 165/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3277 - root_mean_squared_error: 0.2744 - val_loss: 0.4229 - val_root_mean_squared_error: 0.3442
# Epoch 166/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3540 - root_mean_squared_error: 0.2917 - val_loss: 0.4209 - val_root_mean_squared_error: 0.2930
# Epoch 167/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.3552 - root_mean_squared_error: 0.2815 - val_loss: 0.4720 - val_root_mean_squared_error: 0.3586
# Epoch 168/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3390 - root_mean_squared_error: 0.2809 - val_loss: 0.5351 - val_root_mean_squared_error: 0.3867
# Epoch 169/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3460 - root_mean_squared_error: 0.2889 - val_loss: 0.5118 - val_root_mean_squared_error: 0.3379
# Epoch 170/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3210 - root_mean_squared_error: 0.2762 - val_loss: 0.3060 - val_root_mean_squared_error: 0.2807
# Epoch 171/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3556 - root_mean_squared_error: 0.2854 - val_loss: 0.2897 - val_root_mean_squared_error: 0.2487
# Epoch 172/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3147 - root_mean_squared_error: 0.2581 - val_loss: 0.2980 - val_root_mean_squared_error: 0.2608
# Epoch 173/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3463 - root_mean_squared_error: 0.2808 - val_loss: 0.6355 - val_root_mean_squared_error: 0.3815
# Epoch 174/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3288 - root_mean_squared_error: 0.2698 - val_loss: 0.3900 - val_root_mean_squared_error: 0.2956
# Epoch 175/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3411 - root_mean_squared_error: 0.2713 - val_loss: 0.4998 - val_root_mean_squared_error: 0.3446
# Epoch 176/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3435 - root_mean_squared_error: 0.2842 - val_loss: 0.3694 - val_root_mean_squared_error: 0.2723
# Epoch 177/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3426 - root_mean_squared_error: 0.2892 - val_loss: 0.4954 - val_root_mean_squared_error: 0.3778
# Epoch 178/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3581 - root_mean_squared_error: 0.2767 - val_loss: 0.2707 - val_root_mean_squared_error: 0.2405
# Epoch 179/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3454 - root_mean_squared_error: 0.2860 - val_loss: 0.2499 - val_root_mean_squared_error: 0.2366
# Epoch 180/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3440 - root_mean_squared_error: 0.2772 - val_loss: 0.5643 - val_root_mean_squared_error: 0.3791
# Epoch 181/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3380 - root_mean_squared_error: 0.2758 - val_loss: 0.3200 - val_root_mean_squared_error: 0.2643
# Epoch 182/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3562 - root_mean_squared_error: 0.2786 - val_loss: 0.3044 - val_root_mean_squared_error: 0.2614
# Epoch 183/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3493 - root_mean_squared_error: 0.2737 - val_loss: 0.3590 - val_root_mean_squared_error: 0.3013
# Epoch 184/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3291 - root_mean_squared_error: 0.2744 - val_loss: 0.3900 - val_root_mean_squared_error: 0.3143
# Epoch 185/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3328 - root_mean_squared_error: 0.2767 - val_loss: 0.3704 - val_root_mean_squared_error: 0.3098
# Epoch 186/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3315 - root_mean_squared_error: 0.2828 - val_loss: 0.4467 - val_root_mean_squared_error: 0.3286
# Epoch 187/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3311 - root_mean_squared_error: 0.2719 - val_loss: 0.3463 - val_root_mean_squared_error: 0.2785
# Epoch 188/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3239 - root_mean_squared_error: 0.2732 - val_loss: 0.3422 - val_root_mean_squared_error: 0.2542
# Epoch 189/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3466 - root_mean_squared_error: 0.2782 - val_loss: 0.3315 - val_root_mean_squared_error: 0.2740
# Epoch 190/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3376 - root_mean_squared_error: 0.2830 - val_loss: 0.6305 - val_root_mean_squared_error: 0.4329
# Epoch 191/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3348 - root_mean_squared_error: 0.2786 - val_loss: 0.3562 - val_root_mean_squared_error: 0.2706
# Epoch 192/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3388 - root_mean_squared_error: 0.2798 - val_loss: 0.4440 - val_root_mean_squared_error: 0.3230
# Epoch 193/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3306 - root_mean_squared_error: 0.2811 - val_loss: 0.2059 - val_root_mean_squared_error: 0.2267
# Epoch 194/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3273 - root_mean_squared_error: 0.2758 - val_loss: 0.3732 - val_root_mean_squared_error: 0.2898
# Epoch 195/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3269 - root_mean_squared_error: 0.2599 - val_loss: 0.3608 - val_root_mean_squared_error: 0.2909
# Epoch 196/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3411 - root_mean_squared_error: 0.2819 - val_loss: 0.2790 - val_root_mean_squared_error: 0.2320
# Epoch 197/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3687 - root_mean_squared_error: 0.2847 - val_loss: 0.5003 - val_root_mean_squared_error: 0.3351
# Epoch 198/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3579 - root_mean_squared_error: 0.2818 - val_loss: 0.4480 - val_root_mean_squared_error: 0.3291
# Epoch 199/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3301 - root_mean_squared_error: 0.2826 - val_loss: 0.3996 - val_root_mean_squared_error: 0.3286
# Epoch 200/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3338 - root_mean_squared_error: 0.2865 - val_loss: 0.3323 - val_root_mean_squared_error: 0.2660

# %%
# Prediction on test and train data with NN models
for k in params.keys():
    print('Model: %s' % (k))
    model = params[k]['model']

    params[k]['train_pd'] = model.predict(x_train, verbose = 1)
    params[k]['test_pd'] = model.predict(x_test, verbose = 1)
# Out:
# Model: bnn_a1
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_a2
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_a3
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_a4
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_b1
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_b2
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_b3
# 204/204 [==============================] - 2s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# Model: bnn_b4
# 204/204 [==============================] - 1s 3ms/step
# 51/51 [==============================] - 0s 3ms/step

# %%
# Calculate prediction means and stddevs
for k in params.keys():
    params[k]['train_means'] = np.array([np.mean(x) for x in params[k]['train_pd']])
    params[k]['train_stdev'] = np.array([np.std(x) for x in params[k]['train_pd']])
    params[k]['test_means'] = np.array([np.mean(x) for x in params[k]['test_pd']])
    params[k]['test_stdev'] = np.array([np.std(x) for x in params[k]['test_pd']])

# %%
# Calculate test, train RMSE
for k in params.keys():
    params[k]['RMSE_train'] = mean_squared_error(y_train, params[k]['train_means'], squared = False)
    params[k]['RMSE_test'] = mean_squared_error(y_test, params[k]['test_means'], squared = False)

# %%
# Average deviations
for k in params.keys():
    params[k]['avg_train_stdev'] = params[k]['train_stdev'].mean()
    params[k]['avg_test_stdev'] = params[k]['test_stdev'].mean()

# %%
# Metrics

for k in params.keys():
    print('Model: %s' % (params[k]['label']))
    print('\tTrain RMSE: %f' % params[k]['RMSE_train'])
    print('\tTest RMSE: %f' % params[k]['RMSE_test'])
    print('\tAvg Test StDev: %f' % params[k]['avg_train_stdev'])
    print('\tAvg Train StDev: %f' % params[k]['avg_test_stdev'])
# Out:
# Model: BNN A - 64
# 	Train RMSE: 0.137281
# 	Test RMSE: 0.326049
# 	Avg Test StDev: 0.012769
# 	Avg Train StDev: 0.040308
# Model: BNN A - 128
# 	Train RMSE: 0.154422
# 	Test RMSE: 0.292470
# 	Avg Test StDev: 0.014769
# 	Avg Train StDev: 0.036923
# Model: BNN A - 256
# 	Train RMSE: 0.170181
# 	Test RMSE: 0.288764
# 	Avg Test StDev: 0.019769
# 	Avg Train StDev: 0.047385
# Model: BNN A - 512
# 	Train RMSE: 0.207086
# 	Test RMSE: 0.273721
# 	Avg Test StDev: 0.025154
# 	Avg Train StDev: 0.041538
# Model: BNN B - 64
# 	Train RMSE: 0.160048
# 	Test RMSE: 0.289828
# 	Avg Test StDev: 0.017385
# 	Avg Train StDev: 0.036308
# Model: BNN B - 128
# 	Train RMSE: 0.188924
# 	Test RMSE: 0.277904
# 	Avg Test StDev: 0.022462
# 	Avg Train StDev: 0.041231
# Model: BNN B - 256
# 	Train RMSE: 0.215103
# 	Test RMSE: 0.287429
# 	Avg Test StDev: 0.031615
# 	Avg Train StDev: 0.066769
# Model: BNN B - 512
# 	Train RMSE: 0.231882
# 	Test RMSE: 0.271463
# 	Avg Test StDev: 0.034308
# 	Avg Train StDev: 0.057538

# %%
# Plot training loss by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(1, 0, 8))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['loss'], color = colors[i], label = params[k]['label'], alpha = 0.8)
    i += 1
    
#plt.xscale('log')
plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Epoches', fontsize = 12)
plt.ylabel('Loss (-log likelihood)', fontsize = 12)
plt.title('Training Loss By Epoch', fontsize = 18)

plt.show()

# %%
# Plot training error by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(1, 0, 8))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['root_mean_squared_error'], color = colors[i], label = params[k]['label'], alpha = 0.8)
    i += 1
    
plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Epoches', fontsize = 12)
plt.ylabel('Error (RMSE)', fontsize = 12)
plt.title('Training Error By Epoch', fontsize = 18)

plt.show()

# %%
# Plot validation loss by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(1, 0, 8))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['val_loss'], color = colors[i], label = params[k]['label'], alpha = 0.8)
    i += 1
    
plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Epoches', fontsize = 12)
plt.ylabel('Loss (-log likelihood)', fontsize = 12)
plt.title('Validation Loss By Epoch', fontsize = 18)

plt.show()

# %%
# Plot validation error by epoch
fig = plt.figure(figsize = (15, 10))
epoch_arr = np.arange(1, n_epoches + 1)
colors = pl.cm.jet(np.linspace(1, 0, 8))
i = 0

for k in params.keys():
    plt.plot(epoch_arr, params[k]['history'].history['val_root_mean_squared_error'], color = colors[i], label = params[k]['label'], alpha = 0.8)
    i += 1
    
plt.legend(loc = 'best', title = 'Model', fontsize = 12)
plt.xlabel('Epoches', fontsize = 12)
plt.ylabel('Error (RMSE)', fontsize = 12)
plt.title('Validation Error By Epoch', fontsize = 18)

plt.show()

# %%
# Plot distributions
fig, ax = plt.subplots(2, 4, figsize = (30, 12), dpi = 100)
colors = pl.cm.jet(np.linspace(1, 0, 16))
c = 0

k = list(params.keys())

# Plot train
for row in ax:
    for col in row:
        col.hist(params[k[c]]['train_means'], bins = 30, color = colors[c], alpha = 0.5, label = 'Train')
        col.set_title(params[k[c]]['label'])
        c += 1

# Plot test
for row in ax:
    for col in row:
        col.hist(params[k[c-8]]['test_means'], bins = 30, color = colors[c], alpha = 0.5, label = 'Test')
        col.set_title(params[k[c-8]]['label'])
        col.legend(loc = 'best')
        c += 1


# Plot test
fig.suptitle('Prediction Distributions', fontsize = 24)

plt.show()
